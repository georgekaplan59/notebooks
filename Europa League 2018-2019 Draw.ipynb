# %% [markdown]
# # Europa League group stage draw for 2018-2019 season

# %% [markdown]
# The goal of this notebook is to estimate the probabilities of each pair of clubs to be in the same group for the 2018-2019 Europa League group stage. The actual set of fixtures will be the result of the draw on Friday 31 August 2018 in Monaco.
#
# The probabilities are hard to calculate exactly because the draw has to accomplish some UEFA constraints. Therefore, we will estimate an approximation for each probability by means of Montecarlo simulation method. We will assume that the same constraints for the 2017-2018 season are valid in this draw.

# %% [markdown]
# # Regulations
#
# According to the [2018/2019 UEFA Europa League regulations](https://www.uefa.com/MultimediaFiles/Download/Regulations/uefaorg/Regulations/02/55/82/82/2558282_DOWNLOAD.pdf):
#
# * [13.08] For the group stage draw, the 48 clubs are seeded into four groups of 12 in accordance with the club coefficient rankings established at the beginning of the season and with the principles set by the Club Competitions Committee.
#
# * [15.01] Once the play-offs have been completed, the 48 remaining clubs are drawn into __12 groups of four__ in accordance with Paragraph 13.08. __Clubs from the same association cannot be drawn into the same group__.
#
#
# From the [UEFA Europa League 2017/18 group stage draw video](https://www.youtube.com/watch?v=mt9I0sPORWM) the following instructions have been extracted about the technical procedure:
# * The 48 teams have been allocated to 4 pots in accordance with the seeding principles based on the UEFA Club coefficients.
# * Pot 1 will comprise the 12 top clubs in the club coefficient rankings, Pot 2 the following 12 clubs in the rankings, and so on for pots 3 and 4.
# * __For TV coverage reasons clubs from the same Association are paired in order to split their kick-off times that is one early and one late__.
# * For this reason the 12 groups will be distinguished by colors: groups A to F will be red and groups G to L will be blue.
# * __When a paired club is drawn, for example into a red group A to F [Arsenal in Pot 1], the other paired club once it is been drawn will automatically be assigned to one of the 6 blue groups G to L [Everton in Pot 2]__.
# * Please note that based on a decision taken by the UEFA Executive Committee teams from Russia and Ukraine shall not be drawn in the same group.
# * A ball is drawn at random from Pot 1; the team drawn is placed in the first available group in alphabetical order from A to L as indicated by the computer. For example, if the team drawn has all 12 options from A to L available, it will be automatically allocated to Group A; if the team drawn has four options available from G to J, for example, it will be automatically alloated to Group G and so on.
# * It must be noted that the number of options available to a team depends not only on the team's own attributes, for example, winter venue and those are the teams already drawn but also on the attributes of the other teams still to be drawn. This is due to the computer calculations needed to anticipate all possible scenarios and prevent any deadlock situation.
# * This procedure will allocate all teams to the various groups. Then it will be repeated for the teams in Pots 2, 3, and 4, in that order.
# * At the end of the draw a computer will assign the final positions of the teams within their group. These positions will determine the order of the home and away matches.

# %% [markdown]
# * [Season 2017-2018 Pots](https://es.wikipedia.org/wiki/Liga_Europa_de_la_UEFA_2017-18#Fase_de_grupos): to be replaced by the actual pots for the 2018-2019 season
# <table>
#     <tr>
#         <th colspan=4>2017-2018 Season</th>
#     </tr>
#     <tr>
#         <th>Pot 1</th>
#         <th>Pot 2</th>
#         <th>Pot 3</th>
#         <th>Pot 4</th>
#     </tr>
#     <tr>
#         <td>Arsenal (ENG)</td>
#         <td>FCSB (ROU)</td>
#         <td>Astana (KAZ)</td>
#         <td>Apollon Limassol (CYP)</td>
#     </tr>
#     <tr>
#         <td>Zenit (RUS)</td>
#         <td>Ludogorets Razgrad (BUL)</td>
#         <td>Partizan (SRB)</td>
#         <td>İstanbul Başakşehir (TUR)</td>
#     </tr>
#     <tr>
#         <td>Lyon (FRA)</td>
#         <td>BATE Borisov (BLR)</td>
#         <td>Hoffenheim (GER)</td>
#         <td>Konyaspor (TUR)</td>
#     </tr>
#     <tr>
#         <td>Dynamo Kyiv (UKR)</td>
#         <td>Everton (ENG)</td>
#         <td>Köln (GER)</td>
#         <td>Vitesse (NED)</td>
#     </tr>
#     <tr>
#         <td>Villarreal (ESP)</td>
#         <td>Young Boys (SUI)</td>
#         <td>Rijeka (CRO)</td>
#         <td>Slavia Praha (CZE)</td>
#     </tr>
#     <tr>
#         <td>Athletic Club (ESP)</td>
#         <td>Marseille (FRA)</td>
#         <td>Vitória SC (POR)</td>
#         <td>Crvena zvezda (SRB)</td>
#     </tr>
#     <tr>
#         <td>Lazio (ITA)</td>
#         <td>Real Sociedad (ESP)</td>
#         <td>Atalanta (ITA)</td>
#         <td>Skënderbeu (ALB)</td>
#     </tr>
#     <tr>
#         <td>AC Milan (ITA)</td>
#         <td>Maccabi Tel-Aviv (ISR)</td>
#         <td>Zulte Waregem (BEL)</td>
#         <td>AEK Athens (GRE)</td>
#     </tr>
#     <tr>
#         <td>Viktoria Plzeň (CZE)</td>
#         <td>Lokomotiv Moscow (RUS)</td>
#         <td>Zorya Luhansk (UKR)</td>
#         <td>Zlín (CZE)</td>
#     </tr>
#     <tr>
#         <td>Salzburg (AUT)</td>
#         <td>Austria Wien (AUT)</td>
#         <td>Rosenborg (NOR)</td>
#         <td>Lugano (SUI)</td>
#     </tr>
#     <tr>
#         <td>København (DEN)</td>
#         <td>Hertha Berlin (GER)</td>
#         <td>Sheriff Tiraspol (MDA)</td>
#         <td>Vardar (MKD)</td>
#     </tr>
#     <tr>
#         <td>Braga (POR)</td>
#         <td>Nice (FRA)</td>
#         <td>Hapoel Beer-Sheva (ISR)</td>
#         <td>Östersund (SWE)</td>
#     </tr>
# </table>
#
# <!--
# * Clubs ordered by Association:
#
# | Club | Association | Coefficient |
# | ---- | ----------- | ----------- |
# | Skënderbeu | ALB | 6.825 |
# | Salzburg | AUT | 40.57 |
# | Austria Wien | AUT | 17.07 |
# | Zulte Waregem | BEL | 14.48 |
# | BATE Borisov | BLR | 29.475 |
# | Ludogorets Razgrad | BUL | 34.175 |
# | Rijeka | CRO | 15.550 |
# | Apollon Limassol | CYP | 10.71 |
# | Viktoria Plzeň | CZE | 40.635 |
# | Slavia Praha | CZE | 8.135 |
# | Zlín | CZE | 6.635 |
# | København | DEN | 37.800 |
# | Arsenal | ENG | 105.192 |
# | Everton | ENG | 29.192 |
# | Villarreal | ESP | 64.999 |
# | Athletic Club | ESP | 60.999 |
# | Real Sociedad | ESP | 27.499 |
# | Lyon | FRA | 68.833 |
# | Marseille | FRA | 28.333 |
# | Nice | FRA | 16.833 |
# | Hertha Berlin | GER | 16.899 |
# | Hoffenheim | GER | 15.899 |
# | Köln | GER | 15.899 |
# | AEK Athens | GRE | 6.58 |
# | Maccabi Tel-Aviv | ISR | 23.375 |
# | Hapoel Beer-Sheva | ISR | 10.8758 |
# | Lazio | ITA | 56.666 |
# | AC Milan | ITA | 47.666 |
# | Atalanta | ITA | 14.666 |
# | Astana | KAZ | 16.800 |
# | Sheriff Tiraspol | MDA | 11.15 |
# | Vardar | MKD | 5.125 |
# | Vitesse | NED | 9.212 |
# | Rosenborg | NOR | 12.665 |
# | Braga | POR | 37.366 |
# | Vitória SC | POR | 14.866 |
# | FCSB | ROU | 35.370 |
# | Zenit | RUS | 87.106 |
# | Lokomotiv Moscow | RUS | 20.606 |
# | Partizan | SRB | 16.075 |
# | Crvena zvezda | SRB | 7.325 |
# | Young Boys | SUI | 28.915 |
# | Lugano | SUI | 6.415 |
# | Östersund | SWE | 3.945 |
# | İstanbul Başakşehir | TUR | 10.340 |
# | Konyaspor | TUR | 9.84 |
# | Dynamo Kyiv | UKR | 67.526 |
# | Zorya Luhansk | UKR | 13.526 |
# -->

# %% [markdown]
# <!--
# * Season 2018-2019
# <table>
#     <tr>
#         <th colspan=4>2018-2019 Season</th>
#     </tr>
#     <tr>
#         <th>Pot 1</th>
#         <th>Pot 2</th>
#         <th>Pot 3</th>
#         <th>Pot 4</th>
#     </tr>
#     <tr>
#         <td>Sevilla (ESP)</td>
#         <td>Sporting CP (POR)</td>
#         <td>Fenerbahçe (TUR)</td>
#         <td>Standard Liège (BEL)</td>
#     </tr>
#     <tr>
#         <td>Arsenal (ENG)</td>
#         <td>Ludogorets (BUL)</td>
#         <td>Krasnodar (RUS)</td>
#         <td>Zurich (SUI)</td>
#     </tr>
#     <tr>
#         <td>Chelsea (ENG)</td>
#         <td>Kobenhavn (DEN)</td>
#         <td>Maribor (SLO)</td>
#         <td>Midtjylland (DEN)</td>
#     </tr>
#     <tr>
#         <td>Zenith (RUS)</td>
#         <td>Olympique Marseille (FRA)</td>
#         <td>Maccabi Tel-Aviv (ISR)</td>
#         <td>Stade Rennais (FRA)</td>
#     </tr>
#     <tr>
#         <td>Basel (SUI)</td>
#         <td>Sporting Braga (POR)</td>
#         <td>Feyenoord (NED)</td>
#         <td>Red Star Belgrade (SRB)</td>
#     </tr>
#     <tr>
#         <td>Bayer Leverkusen (GER)</td>
#         <td>PAOK (GRE)</td>
#         <td>Real Betis (ESP)</td>
#         <td>AEK (GRE)</td>
#     </tr>
#     <tr>
#         <td>Besiktas (TUR)</td>
#         <td>Milan (ITA)</td>
#         <td>Garabag (AZB)</td>
#         <td>Rosenborg (NOR)</td>
#     </tr>
#     <tr>
#         <td>Olympiakos (GRE)</td>
#         <td>Steaua (ROM)</td>
#         <td>Young Boys (SUI)</td>
#         <td>Vorskla Poltava (UKR)</td>
#     </tr>
#     <tr>
#         <td>Ajax (NED)</td>
#         <td>APOEL (CYP)</td>
#         <td>BATE (BLS)</td>
#         <td>HJK Helsinki (FIN)</td>
#     </tr>
#     <tr>
#         <td>Villarreal (ESP)</td>
#         <td>Gent (BEL)</td>
#         <td>Eintracht Frankfurt (GER)</td>
#         <td>Slavia Praha (CZE)</td>
#     </tr>
#     <tr>
#         <td>Anderlecht (BEL)</td>
#         <td>Racing Genk (BEL)</td>
#         <td>Malmoe (SWE)</td>
#         <td>Akhisarspor (TUR)</td>
#     </tr>
#     <tr>
#         <td>Lazio (ITA)</td>
#         <td>Legia Warsaw (POL)</td>
#         <td>Spartak Moscow (RUS)</td>
#         <td>Jablonec (CZE)</td>
#     </tr>
# </table>
# -->

# %% [markdown]
# # Simulators
#
# A draw simulator has been implemented in order to estimate the probabilities for each pair of clubs to be in the same group. The estimation is based on the [Monte Carlo method](https://en.wikipedia.org/wiki/Monte_Carlo_method).

# %% [markdown]
# ## Imports and constants

# %%
import numpy as np
import networkx as nx
import collections
import time

# %%
# Clubs ordered by association and UEFA ranking
CLUBS = ["Skënderbeu", "Salzburg", "Austria Wien", "Zulte Waregem", "BATE Borisov", "Ludogorets Razgrad", 
         "Rijeka", "Apollon Limassol", "Viktoria Plzeň", "Slavia Praha", "Zlín", "København", 
         "Arsenal", "Everton", "Villarreal", "Athletic Club", "Real Sociedad", "Lyon", 
         "Marseille", "Nice", "Hertha Berlin", "Hoffenheim", "Köln", "AEK Athens", 
         "Maccabi Tel-Aviv", "Hapoel Beer-Sheva", "Lazio", "AC Milan", "Atalanta", "Astana", 
         "Sheriff Tiraspol", "Vardar", "Vitesse", "Rosenborg", "Braga", "Vitória SC", 
         "FCSB", "Zenit", "Lokomotiv Moscow", "Partizan", "Crvena Zvezda", "Young Boys", 
         "Lugano", "Östersund", "İstanbul Başakşehir", "Konyaspor", "Dynamo Kyiv", "Zorya Luhansk"]
# Association of each club
ASSOCIATIONS = ["ALB", "AUT", "AUT", "BEL", "BLR", "BUL", 
                "CRO", "CYP", "CZE", "CZE", "CZE", "DEN", 
                "ENG", "ENG", "ESP", "ESP", "ESP", "FRA", 
                "FRA", "FRA", "GER", "GER", "GER", "GRE", 
                "ISR", "ISR", "ITA", "ITA", "ITA", "KAZ", 
                "MDA", "MKD", "NED", "NOR", "POR", "POR", 
                "ROU", "RUS", "RUS", "SRB", "SRB", "SUI", 
                "SUI", "SWE", "TUR", "TUR", "UKR", "UKR"]
# Pot number of each club
CLUB_POTS = [4, 1, 2, 3, 2, 2, 
             3, 4, 1, 4, 4, 1, 
             1, 2, 1, 1, 2, 1, 
             2, 2, 2, 3, 3, 4, 
             2, 3, 1, 1, 3, 3, 
             3, 4, 4, 3, 1, 3, 
             2, 1, 2, 3, 4, 2, 
             4, 4, 4, 4, 1, 3]
# Number of pots in the draw
NUMBER_OF_POTS = len(set(CLUB_POTS))
# Number of clubs in each pot
CLUBS_PER_POT = len(CLUBS) / NUMBER_OF_POTS
# Groups in first timetable
GROUPS_IN_FIRST_TIMETABLE = list(range(CLUBS_PER_POT/2))
# Groups in second timetable
GROUPS_IN_SECOND_TIMETABLE = list(range(CLUBS_PER_POT/2, CLUBS_PER_POT))

# %%
# Build the list PAIRED_CLUBS (different TV timetable clubs) automatically
# The first two clubs in each association have to be in different TV groups: A-F (19h) or G-L (21h)
# It is required that the list CLUBS is firstly ordered by association and then by UEFA ranking
PAIRED_CLUBS = {}
for association in set(ASSOCIATIONS):
    club_indexes = [idx for idx, c in enumerate(ASSOCIATIONS) if c == association]
    if len(club_indexes) > 1:
        pairing = club_indexes[0:2]
        PAIRED_CLUBS[pairing[0]] = pairing[1]
        PAIRED_CLUBS[pairing[1]] = pairing[0]
        print("Pairing for association %s: %s, %s" % (association, CLUBS[pairing[0]], CLUBS[pairing[1]]))

# Force Russian and Ukrainian clubs to be in different groups
for ukrainian in [idx for idx, c in enumerate(ASSOCIATIONS) if c == "UKR"]:
    ASSOCIATIONS[ukrainian] = "RUS"
# Out:
# Pairing for association ISR: Maccabi Tel-Aviv, Hapoel Beer-Sheva
# Pairing for association UKR: Dynamo Kyiv, Zorya Luhansk
# Pairing for association SUI: Young Boys, Lugano
# Pairing for association GER: Hertha Berlin, Hoffenheim
# Pairing for association ESP: Villarreal, Athletic Club
# Pairing for association POR: Braga, Vitória SC
# Pairing for association SRB: Partizan, Crvena Zvezda
# Pairing for association FRA: Lyon, Marseille
# Pairing for association ENG: Arsenal, Everton
# Pairing for association AUT: Salzburg, Austria Wien
# Pairing for association RUS: Zenit, Lokomotiv Moscow
# Pairing for association TUR: İstanbul Başakşehir, Konyaspor
# Pairing for association ITA: Lazio, AC Milan
# Pairing for association CZE: Viktoria Plzeň, Slavia Praha

# %% [markdown]
# ## Functions

# %%
def copy_list_and_remove_element(element, list_of_elements):
    """
    Return a copy of the list_of_elements having removed element from it.

    Args:
        element: element to be removed from list_of_elements
        list_of_elements: list containing element

    Returns:
        a fresh copy of the list without the element removed
    """
    copied_list = list_of_elements[:]
    copied_list.remove(element)
    return copied_list

def filter_groups(club, groups, updated_draw):
    """
    Valid groups for the club are those having clubs from different associations and 
    satisfying the TV constraints given the current state of the draw.

    Args:
        club: club index for which the list of remaining groups will be filtered
        groups: list of groups that have not been assigned yet
        updated_draw: 2-D numpy array contaiing the current state of the draw

    Returns:
        a filter list of groups
    """
    association = ASSOCIATIONS[club]
    return filter(lambda g: has_no_same_association_club_in_group(updated_draw[g,:], association) \
                  and is_tv_constraint_satisfied(updated_draw, club, g), groups)

def exist_maximum_matching(remaining_clubs, remaining_groups, updated_draw):
    """
    A bipartite graph is built using remaining_clubs (first class) and 
    remaining_groups (second class). For each club, eligible groups are calculated, 
    and for each of these pairs of nodes (1st class, 2nd class) an edge is built. 
    If the maximum matching for this bipartite graph is exactly the sum of 
    the sizes of remaining_clubs and remaining_groups, then there is no dead ends yet.

    Args:
        remaining_clubs: list of indexes of the remaining clubs
        remaining_groups: list of groups that have not been assigned yet
        updated_draw: 2-D numpy array contaiing the current state of the draw

    Returns:
        a boolean
    """
    G = nx.Graph()
    size = len(remaining_clubs)
    G.add_nodes_from(range(size), bipartite=0)
    G.add_nodes_from(range(size, 2*size), bipartite=1)
    for idx, c in enumerate(remaining_clubs):
        for fg in filter_groups(c, remaining_groups, updated_draw):
            g_idx = remaining_groups.index(fg)
            G.add_edge(idx, g_idx + size)
    max_size = len(nx.algorithms.bipartite.maximum_matching(G))
    return max_size == 2 * size

def is_group_in_timetable(group, first_timetable=True):
    groups = GROUPS_IN_FIRST_TIMETABLE if first_timetable else GROUPS_IN_SECOND_TIMETABLE
    return group in groups

def are_groups_in_same_timetable(group1, group2):
    """
    Check if both groups belong to the same timetable.

    Args:
        group1: first group index
        group2: second group index

    Returns:
        a boolean
    """
    return (is_group_in_timetable(group1) and is_group_in_timetable(group2)) or \
           (is_group_in_timetable(group1, False) and is_group_in_timetable(group2, False))

def has_no_same_association_club_in_group(clubs_in_group, association):
    """
    Check whether there is no club in clubs_in_group belonging to the association.

    Args:
        clubs_in_group: list of club indexes
        association: association code to be checked

    Returns:
        a boolean
    """
    already_drawn_clubs_in_group = [club for club in clubs_in_group if club > -1]
    return all([ASSOCIATIONS[club] != association for club in already_drawn_clubs_in_group])

def is_tv_constraint_satisfied(draw, drawn_club_index, group_candidate):
    """
    Check if after assigning the drawn_club into the group_candidate 
    the TV constraints about paired clubs are satisfied.

    Args:
        draw: 2-D numpy array contaiing the current state of the draw
        drawn_club_index: index of the drawn club
        group_candidate: group candidate to be assigned to the current drawn club

    Returns:
        a boolean
    """
    if drawn_club_index in PAIRED_CLUBS:
        i,j = np.where(draw == PAIRED_CLUBS[drawn_club_index])
        if (len(i) > 0) and are_groups_in_same_timetable(i[0], group_candidate):
            return False
    return True

def get_numbers_of_pending_clubs_tv_constrained(draw, remaining_clubs):
    """
    Calculate the number of clubs in remaining_clubs having a paired club already drawn
    in both TV timetable group categories: 19h and 21h.
    Return a pair of integers.

    Args:
        draw: 2-D numpy array contaiing the current state of the draw
        remaining_clubs: list of indexes of the remaining clubs

    Returns:
        a tuple of integers
    """
    clubs_in_19h = 0
    clubs_in_21h = 0
    for c in remaining_clubs:
        if c in PAIRED_CLUBS:
            g, p = np.where(draw == PAIRED_CLUBS[c])
            if len(g) > 0:
                if is_group_in_timetable(g[0]):
                    clubs_in_21h += 1
                else:
                    clubs_in_19h += 1
    return clubs_in_19h, clubs_in_21h

def has_no_dead_ends(draw, drawn_club_index, group_candidate, remaining_clubs, groups_available, pot):
    """
    Check whether after assigning drawn_club to group, 
    there will be a dead end in the draw of remaining_clubs and groups_available.

    Args:
        draw: 2-D numpy array contaiing the current state of the draw
        drawn_club_index: index of the drawn club
        group_candidate: group candidate to be assigned to the current drawn club
        remaining_clubs: list of indexes of the remaining clubs
        groups_available: groups that have not been assigned yet
        pot: pot from which the current club has been drawn

    Returns:
        a boolean
    """
    updated_draw = np.copy(draw)
    updated_draw[group_candidate, pot] = drawn_club_index
    remaining_groups = copy_list_and_remove_element(group_candidate, groups_available)
    paired_clubs_in_pot = sum([1 if c in PAIRED_CLUBS and PAIRED_CLUBS[c] in remaining_clubs else 0 \
                               for c in remaining_clubs]) 
    pairs = paired_clubs_in_pot / 2
    clubs_forced_in_19h, clubs_forced_in_21h = get_numbers_of_pending_clubs_tv_constrained(updated_draw, 
                                                                                           remaining_clubs)
    groups_in_19h = len([g for g in remaining_groups if is_group_in_timetable(g)])
    groups_in_21h = len([g for g in remaining_groups if is_group_in_timetable(g, False)])
    if (groups_in_19h < pairs + clubs_forced_in_19h) or (groups_in_21h < pairs + clubs_forced_in_21h):
        return False
    return exist_maximum_matching(remaining_clubs, remaining_groups, updated_draw)

def get_feasible_groups(draw, drawn_club_index, remaining_clubs, groups_available, pot):
    """
    Return the first feasible group for drawn_club satisfying the draw constraints 
    about TV timetables, same association clubs, and dead ends.
    The function is prepared to return a list of feasible groups 
    instead of the first one in lexicographical order.

    Args:
        draw: 2-D numpy array contaiing the current state of the draw
        drawn_club_index: index of the drawn club
        remaining_clubs: list of indexes of the remaining clubs
        groups_available: groups that have not been assigned yet
        pot: pot from which the current club has been drawn

    Returns:
        the index of the first feasible group available for the drawn club
    """
    feasible_groups = []
    association = ASSOCIATIONS[drawn_club_index]
    for group in groups_available:
        if is_tv_constraint_satisfied(draw, drawn_club_index, group):
            if has_no_same_association_club_in_group(draw[group,:], association):
                if has_no_dead_ends(draw, drawn_club_index, group, remaining_clubs, groups_available, pot):
                    feasible_groups.append(group)
                    return feasible_groups
    return feasible_groups

def check_draw_validity(draw):
    """
    Check whether or not the draw satisfies all the constraints about 
    TV timetables and same association clubs.

    Args:
        draw: a [CLUBS_PER_POT]x[NUMBER_OF_POTS] numpy 2D-array containing club indexes

    Returns:
        a boolean
    """
    # Checking TV constraints
    for c1, c2 in PAIRED_CLUBS.items():
        g1, _ = np.where(draw == c1)
        g2, _ = np.where(draw == c2)
        if are_groups_in_same_timetable(g1[0], g2[0]):
            timetable = '19h' if is_group_in_timetable(g1[0]) else '21h'
            print("Teams %s and %s must be in opposite legs in draw, but they are in %s side" % (CLUBS[c1], 
                                                                                                 CLUBS[c2], 
                                                                                                 timetable))
            return False
    # Checking association constraint
    for group in range(CLUBS_PER_POT):
        valid = len(set([ASSOCIATIONS[club] for club in draw[group,:]])) == NUMBER_OF_POTS
        if not valid:
            print("Group %s (%s): %s" % (chr(65+group), 
                                         valid, 
                                         ", ".join([CLUBS[club] for club in draw[group,:]])))
            return False
    return True

def show_draw_result(draw):
    """
    Print the result of a draw in the form of group composition.

    Args:
        draw: a [CLUBS_PER_POT]x[NUMBER_OF_POTS] numpy 2D-array containing club indexes
    """
    for group in range(CLUBS_PER_POT):
        print("Group %s: %s" % (chr(65+group), ", ".join([CLUBS[club] for club in draw[group,:]])))

def simulate_draw(simulations, verbose=False, show_errors=True):
    """
    Simulate the number of draw required.

    Args:
        simulations: The number of draws to be simulated
        verbose: Trace the draw development printing pot compositions and clubs drawn
        show_errors: Print an error message where a club doesn't have any feasible group

    Returns:
        a [simulations]x[CLUBS_PER_POT]x[NUMBER_OF_POTS] numpy 3D-array containing club indexes
    """
    draws = np.full((simulations, CLUBS_PER_POT, NUMBER_OF_POTS), -1)
    simulation = 0
    while simulation < simulations:
        feasible = True
        draws[simulation] = np.full((CLUBS_PER_POT, NUMBER_OF_POTS), -1)
        draw = draws[simulation]
        for pot_idx in range(NUMBER_OF_POTS):
            clubs_in_pot = [idx for idx, pot in enumerate(CLUB_POTS) if pot == pot_idx+1]
            if verbose:
                print("\nPot #%d:%s" % (pot_idx+1, ', '.join([CLUBS[idx] for idx in clubs_in_pot])))
            groups_available = range(CLUBS_PER_POT)
            while len(clubs_in_pot) > 0:
                drawn_club = np.random.choice(clubs_in_pot)
                clubs_in_pot.remove(drawn_club)
                feasible_groups = get_feasible_groups(draw, drawn_club, 
                                                      clubs_in_pot, groups_available, pot_idx)
                if len(feasible_groups) == 0:
                    if show_errors:
                        print("Not group available for club: %s, %s" % (CLUBS[drawn_club], groups_available))
                    feasible = False
                    break
                assigned_group = feasible_groups[0]
                groups_available.remove(assigned_group)
                if verbose:
                    print("\t -> %s to group %d\t%s" % (CLUBS[drawn_club], assigned_group, feasible_groups))
                draw[assigned_group, pot_idx] = drawn_club
            if not feasible:
                break
        if feasible and check_draw_validity(draw):
            simulation += 1
    return draws

def estimate_probabilities(draws):
    """
    Using all the simulated draws, the probabilities of each pair of club to be in the same group are estimated.
    Probabilities are real numbers in the interval [0, 1].

    Args:
        draws: [simulations]x[CLUBS_PER_POT]x[NUMBER_OF_POTS] numpy 3D-array containing the simulated draws

    Returns:
        a 48x48 numpy 2D-array containing the probability for each pair of clubs belonging to the same group
    """
    simulations = draws.shape[0]
    total_events = float(simulations)  # total number of events
    estimations = np.full((len(CLUBS), len(CLUBS)), 0,  dtype=np.float32)  # probability estimations

    # For each pair of teams, calculate the probability of belonging to the same group
    for club in range(len(CLUBS)):
        pot = CLUB_POTS[club]-1  # Pot to which the current team belongs
        rivals = np.array([draws[i,np.where(draws[i,:,:] == club)[0][0],:] for i in range(simulations)])
        estimations[club, club] = 1  # each team has a prob=1 of belonging to its own group
        rivals = rivals.flatten()
        counts = collections.Counter(rivals)
        for rival, counter in counts.items():
            estimations[club, rival] = float(counter)/total_events

    return estimations

# %% [markdown]
# ## Simulations

# %%
start = time.time()
simulations = 100000
draws = simulate_draw(simulations, verbose=False)
end = time.time()
print("Elapsed time for %d simulated draws: %.3f" % (simulations, end-start))
# Out:
# Elapsed time for 100000 simulated draws: 3708.884

# %%
print("Showing one of the simulated draws:\n")
show_draw_result(draws[0])
# Out:
# Showing one of the simulated draws:
#
# Group A: Lyon, Austria Wien, Köln, AEK Athens
# Group B: Viktoria Plzeň, Nice, Partizan, Vardar
# Group C: Villarreal, Lokomotiv Moscow, Sheriff Tiraspol, Zlín
# Group D: Lazio, Young Boys, Vitória SC, Skënderbeu
# Group E: Arsenal, FCSB, Astana, İstanbul Başakşehir
# Group F: Dynamo Kyiv, Maccabi Tel-Aviv, Hoffenheim, Vitesse
# Group G: København, Hertha Berlin, Zorya Luhansk, Lugano
# Group H: Athletic Club, Marseille, Hapoel Beer-Sheva, Crvena Zvezda
# Group I: AC Milan, Everton, Rosenborg, Östersund
# Group J: Salzburg, Real Sociedad, Atalanta, Konyaspor
# Group K: Braga, BATE Borisov, Rijeka, Slavia Praha
# Group L: Zenit, Ludogorets Razgrad, Zulte Waregem, Apollon Limassol

# %% [markdown]
# ## Probability estimations

# %%
estimations = estimate_probabilities(draws)

# %%
number_of_subsamples = 100
subsamples_estimations = np.full((number_of_subsamples, estimations.shape[0], estimations.shape[1]), 
                                 0,  
                                 dtype=np.float32)

for idx, subsample in enumerate(np.array_split(draws, number_of_subsamples)):
    subsamples_estimations[idx, :] = estimate_probabilities(subsample)

# %%
error_estimations = np.sqrt(np.var(subsamples_estimations, axis=0)/number_of_subsamples)

# %% [markdown]
# ## Results

# %%
for pot in range(1, NUMBER_OF_POTS+1):
    print("Clubs in pot %d" % pot)
    for club in np.where(np.array(CLUB_POTS) == pot)[0]:
        print("\t%s" % CLUBS[club])
        for other_pot in filter(lambda x: x <> pot-1, range(NUMBER_OF_POTS)):
            rivals = np.where(np.array(CLUB_POTS) == other_pot+1)[0]
            print("\t\tRivals in pot %d" % (other_pot+1))
            probabilities = filter(lambda x: x[1] > 0, zip(rivals, estimations[club,rivals]))
            probabilities = sorted(probabilities, key=lambda x: -x[1])
            for rival, p in probabilities:
                print("\t\t\t%s: %.2f%% ± %.2f%%" % (CLUBS[rival], 
                                                             p*100, 
                                                             2*error_estimations[club,rival]*100))
            if not np.isclose([sum(estimations[club,rivals])], [1]):
                print("\t\t\tThe sum of all the probabilities must be equal to 100%")
# Out:
# Clubs in pot 1
# 	Salzburg
# 		Rivals in pot 2
# 			Real Sociedad: 10.54% ± 0.20%
# 			Nice: 9.73% ± 0.24%
# 			Lokomotiv Moscow: 9.64% ± 0.16%
# 			BATE Borisov: 8.92% ± 0.19%
# 			Hertha Berlin: 8.87% ± 0.19%
# 			Maccabi Tel-Aviv: 8.87% ± 0.20%
# 			Ludogorets Razgrad: 8.85% ± 0.18%
# 			Young Boys: 8.85% ± 0.19%
# 			FCSB: 8.78% ± 0.19%
# 			Everton: 8.52% ± 0.18%
# 			Marseille: 8.45% ± 0.20%
# 		Rivals in pot 3
# 			Atalanta: 9.99% ± 0.22%
# 			Zorya Luhansk: 9.98% ± 0.18%
# 			Vitória SC: 8.53% ± 0.20%
# 			Rijeka: 8.28% ± 0.18%
# 			Rosenborg: 8.28% ± 0.18%
# 			Zulte Waregem: 8.25% ± 0.16%
# 			Köln: 8.22% ± 0.17%
# 			Astana: 8.18% ± 0.19%
# 			Sheriff Tiraspol: 8.15% ± 0.17%
# 			Partizan: 8.04% ± 0.17%
# 			Hapoel Beer-Sheva: 7.14% ± 0.17%
# 			Hoffenheim: 6.96% ± 0.16%
# 		Rivals in pot 4
# 			Zlín: 9.27% ± 0.18%
# 			Slavia Praha: 8.91% ± 0.20%
# 			Konyaspor: 8.44% ± 0.19%
# 			Skënderbeu: 8.43% ± 0.16%
# 			İstanbul Başakşehir: 8.42% ± 0.18%
# 			Vardar: 8.35% ± 0.16%
# 			Apollon Limassol: 8.33% ± 0.19%
# 			AEK Athens: 8.28% ± 0.19%
# 			Vitesse: 8.28% ± 0.17%
# 			Östersund: 8.25% ± 0.17%
# 			Crvena Zvezda: 7.82% ± 0.15%
# 			Lugano: 7.22% ± 0.17%
# 	Viktoria Plzeň
# 		Rivals in pot 2
# 			Lokomotiv Moscow: 9.79% ± 0.18%
# 			Real Sociedad: 9.25% ± 0.19%
# 			Marseille: 8.78% ± 0.18%
# 			Everton: 8.70% ± 0.19%
# 			Austria Wien: 8.62% ± 0.16%
# 			Nice: 8.56% ± 0.16%
# 			Young Boys: 7.81% ± 0.16%
# 			BATE Borisov: 7.76% ± 0.15%
# 			Maccabi Tel-Aviv: 7.74% ± 0.15%
# 			Hertha Berlin: 7.67% ± 0.16%
# 			Ludogorets Razgrad: 7.66% ± 0.17%
# 			FCSB: 7.65% ± 0.15%
# 		Rivals in pot 3
# 			Zorya Luhansk: 9.94% ± 0.20%
# 			Atalanta: 9.68% ± 0.21%
# 			Vitória SC: 8.52% ± 0.19%
# 			Hapoel Beer-Sheva: 8.26% ± 0.18%
# 			Hoffenheim: 8.05% ± 0.18%
# 			Köln: 8.01% ± 0.17%
# 			Zulte Waregem: 7.99% ± 0.18%
# 			Rijeka: 7.97% ± 0.17%
# 			Astana: 7.97% ± 0.18%
# 			Rosenborg: 7.94% ± 0.18%
# 			Sheriff Tiraspol: 7.85% ± 0.15%
# 			Partizan: 7.83% ± 0.18%
# 		Rivals in pot 4
# 			Östersund: 10.71% ± 0.20%
# 			AEK Athens: 10.70% ± 0.21%
# 			Skënderbeu: 10.68% ± 0.22%
# 			Vardar: 10.68% ± 0.18%
# 			Vitesse: 10.63% ± 0.21%
# 			Apollon Limassol: 10.59% ± 0.19%
# 			İstanbul Başakşehir: 9.34% ± 0.18%
# 			Konyaspor: 9.13% ± 0.18%
# 			Lugano: 8.86% ± 0.18%
# 			Crvena Zvezda: 8.69% ± 0.18%
# 	København
# 		Rivals in pot 2
# 			Lokomotiv Moscow: 9.77% ± 0.19%
# 			Real Sociedad: 9.47% ± 0.20%
# 			Austria Wien: 8.77% ± 0.17%
# 			Everton: 8.60% ± 0.17%
# 			Marseille: 8.52% ± 0.17%
# 			Nice: 8.51% ± 0.17%
# 			Young Boys: 7.81% ± 0.18%
# 			Maccabi Tel-Aviv: 7.80% ± 0.16%
# 			BATE Borisov: 7.79% ± 0.14%
# 			FCSB: 7.75% ± 0.16%
# 			Hertha Berlin: 7.69% ± 0.17%
# 			Ludogorets Razgrad: 7.53% ± 0.15%
# 		Rivals in pot 3
# 			Zorya Luhansk: 9.86% ± 0.19%
# 			Atalanta: 9.60% ± 0.19%
# 			Vitória SC: 8.72% ± 0.17%
# 			Köln: 8.13% ± 0.16%
# 			Hapoel Beer-Sheva: 8.07% ± 0.17%
# 			Hoffenheim: 8.06% ± 0.19%
# 			Zulte Waregem: 8.01% ± 0.19%
# 			Sheriff Tiraspol: 7.99% ± 0.16%
# 			Rosenborg: 7.91% ± 0.17%
# 			Rijeka: 7.90% ± 0.16%
# 			Partizan: 7.90% ± 0.16%
# 			Astana: 7.85% ± 0.18%
# 		Rivals in pot 4
# 			Zlín: 9.17% ± 0.18%
# 			Slavia Praha: 8.89% ± 0.19%
# 			Lugano: 8.39% ± 0.19%
# 			AEK Athens: 8.28% ± 0.17%
# 			Vardar: 8.22% ± 0.17%
# 			Apollon Limassol: 8.21% ± 0.18%
# 			Konyaspor: 8.21% ± 0.19%
# 			Östersund: 8.18% ± 0.18%
# 			İstanbul Başakşehir: 8.13% ± 0.17%
# 			Crvena Zvezda: 8.12% ± 0.17%
# 			Skënderbeu: 8.12% ± 0.14%
# 			Vitesse: 8.10% ± 0.17%
# 	Arsenal
# 		Rivals in pot 2
# 			Real Sociedad: 10.49% ± 0.19%
# 			Nice: 9.79% ± 0.17%
# 			Lokomotiv Moscow: 9.31% ± 0.17%
# 			Hertha Berlin: 9.12% ± 0.16%
# 			BATE Borisov: 8.90% ± 0.19%
# 			FCSB: 8.87% ± 0.19%
# 			Maccabi Tel-Aviv: 8.86% ± 0.18%
# 			Ludogorets Razgrad: 8.84% ± 0.20%
# 			Young Boys: 8.76% ± 0.19%
# 			Marseille: 8.57% ± 0.16%
# 			Austria Wien: 8.49% ± 0.18%
# 		Rivals in pot 3
# 			Zorya Luhansk: 10.05% ± 0.21%
# 			Atalanta: 9.87% ± 0.19%
# 			Vitória SC: 8.67% ± 0.20%
# 			Rosenborg: 8.31% ± 0.16%
# 			Partizan: 8.28% ± 0.17%
# 			Sheriff Tiraspol: 8.28% ± 0.19%
# 			Zulte Waregem: 8.27% ± 0.18%
# 			Köln: 8.15% ± 0.17%
# 			Rijeka: 8.09% ± 0.16%
# 			Astana: 8.06% ± 0.16%
# 			Hoffenheim: 7.01% ± 0.14%
# 			Hapoel Beer-Sheva: 6.96% ± 0.14%
# 		Rivals in pot 4
# 			Zlín: 9.47% ± 0.18%
# 			Slavia Praha: 8.86% ± 0.18%
# 			Apollon Limassol: 8.43% ± 0.17%
# 			Vitesse: 8.42% ± 0.18%
# 			Skënderbeu: 8.41% ± 0.18%
# 			Vardar: 8.38% ± 0.19%
# 			Konyaspor: 8.29% ± 0.15%
# 			İstanbul Başakşehir: 8.27% ± 0.17%
# 			Östersund: 8.24% ± 0.17%
# 			AEK Athens: 8.22% ± 0.18%
# 			Crvena Zvezda: 7.86% ± 0.17%
# 			Lugano: 7.14% ± 0.17%
# 	Villarreal
# 		Rivals in pot 2
# 			Lokomotiv Moscow: 10.75% ± 0.19%
# 			Marseille: 9.95% ± 0.17%
# 			Everton: 9.67% ± 0.17%
# 			Austria Wien: 9.62% ± 0.18%
# 			Nice: 9.33% ± 0.17%
# 			FCSB: 8.69% ± 0.17%
# 			Maccabi Tel-Aviv: 8.48% ± 0.18%
# 			Young Boys: 8.47% ± 0.18%
# 			BATE Borisov: 8.46% ± 0.18%
# 			Ludogorets Razgrad: 8.34% ± 0.17%
# 			Hertha Berlin: 8.23% ± 0.16%
# 		Rivals in pot 3
# 			Zorya Luhansk: 9.73% ± 0.17%
# 			Atalanta: 9.38% ± 0.16%
# 			Vitória SC: 9.25% ± 0.18%
# 			Hoffenheim: 9.23% ± 0.18%
# 			Hapoel Beer-Sheva: 9.13% ± 0.20%
# 			Rijeka: 7.72% ± 0.15%
# 			Partizan: 7.71% ± 0.17%
# 			Sheriff Tiraspol: 7.68% ± 0.20%
# 			Astana: 7.62% ± 0.16%
# 			Köln: 7.56% ± 0.16%
# 			Zulte Waregem: 7.51% ± 0.16%
# 			Rosenborg: 7.48% ± 0.16%
# 		Rivals in pot 4
# 			Slavia Praha: 9.45% ± 0.20%
# 			Lugano: 9.40% ± 0.19%
# 			Crvena Zvezda: 9.36% ± 0.19%
# 			Zlín: 8.71% ± 0.18%
# 			Konyaspor: 8.11% ± 0.15%
# 			İstanbul Başakşehir: 8.10% ± 0.17%
# 			Skënderbeu: 7.91% ± 0.16%
# 			Vardar: 7.84% ± 0.17%
# 			Östersund: 7.82% ± 0.16%
# 			Vitesse: 7.78% ± 0.19%
# 			Apollon Limassol: 7.78% ± 0.16%
# 			AEK Athens: 7.73% ± 0.20%
# 	Athletic Club
# 		Rivals in pot 2
# 			Lokomotiv Moscow: 10.68% ± 0.18%
# 			Everton: 9.77% ± 0.19%
# 			Marseille: 9.76% ± 0.17%
# 			Austria Wien: 9.70% ± 0.21%
# 			Nice: 9.33% ± 0.22%
# 			Young Boys: 8.54% ± 0.18%
# 			FCSB: 8.50% ± 0.19%
# 			Ludogorets Razgrad: 8.47% ± 0.19%
# 			Hertha Berlin: 8.45% ± 0.16%
# 			Maccabi Tel-Aviv: 8.44% ± 0.16%
# 			BATE Borisov: 8.37% ± 0.18%
# 		Rivals in pot 3
# 			Zorya Luhansk: 9.78% ± 0.20%
# 			Vitória SC: 9.37% ± 0.19%
# 			Atalanta: 9.34% ± 0.18%
# 			Hoffenheim: 9.32% ± 0.19%
# 			Hapoel Beer-Sheva: 9.25% ± 0.18%
# 			Rijeka: 7.69% ± 0.15%
# 			Köln: 7.62% ± 0.14%
# 			Astana: 7.58% ± 0.17%
# 			Sheriff Tiraspol: 7.58% ± 0.17%
# 			Partizan: 7.55% ± 0.16%
# 			Zulte Waregem: 7.54% ± 0.19%
# 			Rosenborg: 7.38% ± 0.18%
# 		Rivals in pot 4
# 			Crvena Zvezda: 9.53% ± 0.17%
# 			Slavia Praha: 9.44% ± 0.20%
# 			Lugano: 9.31% ± 0.18%
# 			Zlín: 8.64% ± 0.18%
# 			İstanbul Başakşehir: 8.12% ± 0.15%
# 			Konyaspor: 8.10% ± 0.18%
# 			Skënderbeu: 7.93% ± 0.16%
# 			AEK Athens: 7.90% ± 0.18%
# 			Östersund: 7.83% ± 0.18%
# 			Vitesse: 7.78% ± 0.17%
# 			Apollon Limassol: 7.71% ± 0.18%
# 			Vardar: 7.71% ± 0.20%
# 	Lyon
# 		Rivals in pot 2
# 			Real Sociedad: 11.63% ± 0.21%
# 			Lokomotiv Moscow: 10.23% ± 0.20%
# 			Hertha Berlin: 10.13% ± 0.21%
# 			BATE Borisov: 9.92% ± 0.20%
# 			Young Boys: 9.92% ± 0.19%
# 			Maccabi Tel-Aviv: 9.88% ± 0.20%
# 			FCSB: 9.86% ± 0.19%
# 			Ludogorets Razgrad: 9.68% ± 0.16%
# 			Austria Wien: 9.38% ± 0.20%
# 			Everton: 9.37% ± 0.17%
# 		Rivals in pot 3
# 			Zorya Luhansk: 9.97% ± 0.16%
# 			Atalanta: 9.70% ± 0.17%
# 			Vitória SC: 8.67% ± 0.19%
# 			Partizan: 8.38% ± 0.17%
# 			Rosenborg: 8.31% ± 0.18%
# 			Astana: 8.24% ± 0.17%
# 			Rijeka: 8.23% ± 0.19%
# 			Sheriff Tiraspol: 8.20% ± 0.16%
# 			Zulte Waregem: 8.18% ± 0.18%
# 			Köln: 8.13% ± 0.17%
# 			Hoffenheim: 7.00% ± 0.14%
# 			Hapoel Beer-Sheva: 6.99% ± 0.17%
# 		Rivals in pot 4
# 			Zlín: 9.41% ± 0.18%
# 			Slavia Praha: 8.86% ± 0.17%
# 			Apollon Limassol: 8.44% ± 0.18%
# 			Östersund: 8.41% ± 0.17%
# 			İstanbul Başakşehir: 8.39% ± 0.18%
# 			AEK Athens: 8.35% ± 0.15%
# 			Konyaspor: 8.35% ± 0.19%
# 			Skënderbeu: 8.32% ± 0.18%
# 			Vitesse: 8.31% ± 0.17%
# 			Vardar: 8.29% ± 0.15%
# 			Crvena Zvezda: 7.79% ± 0.15%
# 			Lugano: 7.09% ± 0.16%
# 	Lazio
# 		Rivals in pot 2
# 			Lokomotiv Moscow: 10.09% ± 0.19%
# 			Real Sociedad: 9.20% ± 0.20%
# 			Marseille: 9.16% ± 0.17%
# 			Everton: 9.15% ± 0.17%
# 			Austria Wien: 8.94% ± 0.16%
# 			Nice: 8.55% ± 0.20%
# 			Ludogorets Razgrad: 7.79% ± 0.18%
# 			BATE Borisov: 7.67% ± 0.17%
# 			Hertha Berlin: 7.47% ± 0.17%
# 			Maccabi Tel-Aviv: 7.42% ± 0.14%
# 			Young Boys: 7.30% ± 0.14%
# 			FCSB: 7.28% ± 0.17%
# 		Rivals in pot 3
# 			Zorya Luhansk: 10.51% ± 0.18%
# 			Hoffenheim: 9.98% ± 0.20%
# 			Vitória SC: 9.84% ± 0.17%
# 			Hapoel Beer-Sheva: 9.81% ± 0.22%
# 			Zulte Waregem: 8.74% ± 0.17%
# 			Partizan: 8.60% ± 0.15%
# 			Köln: 8.56% ± 0.19%
# 			Rosenborg: 8.56% ± 0.18%
# 			Sheriff Tiraspol: 8.50% ± 0.18%
# 			Rijeka: 8.48% ± 0.17%
# 			Astana: 8.43% ± 0.16%
# 		Rivals in pot 4
# 			Slavia Praha: 9.44% ± 0.22%
# 			Lugano: 9.41% ± 0.22%
# 			Crvena Zvezda: 9.35% ± 0.19%
# 			Zlín: 8.58% ± 0.19%
# 			İstanbul Başakşehir: 8.35% ± 0.19%
# 			Konyaspor: 8.15% ± 0.18%
# 			AEK Athens: 7.92% ± 0.17%
# 			Östersund: 7.86% ± 0.16%
# 			Vardar: 7.84% ± 0.16%
# 			Apollon Limassol: 7.80% ± 0.17%
# 			Vitesse: 7.67% ± 0.17%
# 			Skënderbeu: 7.63% ± 0.17%
# 	AC Milan
# 		Rivals in pot 2
# 			Lokomotiv Moscow: 10.00% ± 0.21%
# 			Austria Wien: 9.28% ± 0.18%
# 			Real Sociedad: 9.26% ± 0.16%
# 			Everton: 9.16% ± 0.19%
# 			Marseille: 9.15% ± 0.16%
# 			Nice: 8.56% ± 0.16%
# 			FCSB: 7.59% ± 0.17%
# 			Young Boys: 7.48% ± 0.17%
# 			Ludogorets Razgrad: 7.46% ± 0.17%
# 			Hertha Berlin: 7.43% ± 0.17%
# 			BATE Borisov: 7.31% ± 0.15%
# 			Maccabi Tel-Aviv: 7.31% ± 0.16%
# 		Rivals in pot 3
# 			Zorya Luhansk: 10.30% ± 0.20%
# 			Hapoel Beer-Sheva: 9.88% ± 0.19%
# 			Hoffenheim: 9.88% ± 0.19%
# 			Vitória SC: 9.69% ± 0.17%
# 			Rosenborg: 8.77% ± 0.17%
# 			Astana: 8.68% ± 0.19%
# 			Partizan: 8.66% ± 0.17%
# 			Sheriff Tiraspol: 8.61% ± 0.16%
# 			Rijeka: 8.56% ± 0.18%
# 			Zulte Waregem: 8.50% ± 0.19%
# 			Köln: 8.47% ± 0.16%
# 		Rivals in pot 4
# 			Slavia Praha: 9.52% ± 0.19%
# 			Crvena Zvezda: 9.50% ± 0.17%
# 			Lugano: 9.39% ± 0.20%
# 			Zlín: 8.76% ± 0.19%
# 			Konyaspor: 8.15% ± 0.16%
# 			İstanbul Başakşehir: 8.04% ± 0.17%
# 			Östersund: 7.91% ± 0.19%
# 			Apollon Limassol: 7.86% ± 0.16%
# 			Vitesse: 7.83% ± 0.19%
# 			AEK Athens: 7.79% ± 0.16%
# 			Vardar: 7.70% ± 0.18%
# 			Skënderbeu: 7.55% ± 0.19%
# 	Braga
# 		Rivals in pot 2
# 			Lokomotiv Moscow: 9.72% ± 0.17%
# 			Real Sociedad: 9.52% ± 0.19%
# 			Marseille: 8.77% ± 0.18%
# 			Nice: 8.61% ± 0.18%
# 			Austria Wien: 8.60% ± 0.18%
# 			Everton: 8.56% ± 0.19%
# 			FCSB: 7.90% ± 0.17%
# 			Ludogorets Razgrad: 7.75% ± 0.18%
# 			Maccabi Tel-Aviv: 7.72% ± 0.16%
# 			Young Boys: 7.63% ± 0.17%
# 			BATE Borisov: 7.63% ± 0.18%
# 			Hertha Berlin: 7.60% ± 0.15%
# 		Rivals in pot 3
# 			Atalanta: 10.83% ± 0.16%
# 			Zorya Luhansk: 9.88% ± 0.16%
# 			Köln: 9.32% ± 0.18%
# 			Rijeka: 9.18% ± 0.18%
# 			Sheriff Tiraspol: 9.04% ± 0.19%
# 			Rosenborg: 9.01% ± 0.19%
# 			Astana: 8.96% ± 0.18%
# 			Partizan: 8.94% ± 0.18%
# 			Zulte Waregem: 8.86% ± 0.17%
# 			Hapoel Beer-Sheva: 8.00% ± 0.16%
# 			Hoffenheim: 7.99% ± 0.18%
# 		Rivals in pot 4
# 			Zlín: 9.40% ± 0.19%
# 			Slavia Praha: 8.81% ± 0.19%
# 			İstanbul Başakşehir: 8.41% ± 0.19%
# 			Skënderbeu: 8.36% ± 0.16%
# 			Lugano: 8.36% ± 0.16%
# 			AEK Athens: 8.35% ± 0.15%
# 			Vitesse: 8.34% ± 0.17%
# 			Vardar: 8.29% ± 0.17%
# 			Östersund: 8.27% ± 0.16%
# 			Konyaspor: 8.22% ± 0.18%
# 			Apollon Limassol: 8.17% ± 0.15%
# 			Crvena Zvezda: 7.02% ± 0.17%
# 	Zenit
# 		Rivals in pot 2
# 			Real Sociedad: 10.70% ± 0.18%
# 			Nice: 9.96% ± 0.19%
# 			Ludogorets Razgrad: 8.99% ± 0.19%
# 			Young Boys: 8.98% ± 0.21%
# 			Maccabi Tel-Aviv: 8.90% ± 0.20%
# 			Hertha Berlin: 8.85% ± 0.20%
# 			BATE Borisov: 8.81% ± 0.17%
# 			FCSB: 8.80% ± 0.17%
# 			Austria Wien: 8.71% ± 0.18%
# 			Marseille: 8.71% ± 0.18%
# 			Everton: 8.59% ± 0.17%
# 		Rivals in pot 3
# 			Atalanta: 10.55% ± 0.21%
# 			Vitória SC: 10.03% ± 0.19%
# 			Astana: 9.12% ± 0.18%
# 			Partizan: 9.07% ± 0.18%
# 			Zulte Waregem: 9.02% ± 0.18%
# 			Rosenborg: 8.97% ± 0.16%
# 			Köln: 8.93% ± 0.21%
# 			Sheriff Tiraspol: 8.91% ± 0.17%
# 			Rijeka: 8.91% ± 0.18%
# 			Hapoel Beer-Sheva: 8.25% ± 0.16%
# 			Hoffenheim: 8.25% ± 0.17%
# 		Rivals in pot 4
# 			Zlín: 9.31% ± 0.17%
# 			Slavia Praha: 9.01% ± 0.19%
# 			Vitesse: 8.48% ± 0.17%
# 			Vardar: 8.47% ± 0.16%
# 			Konyaspor: 8.40% ± 0.16%
# 			Apollon Limassol: 8.39% ± 0.18%
# 			Skënderbeu: 8.31% ± 0.17%
# 			İstanbul Başakşehir: 8.23% ± 0.17%
# 			Östersund: 8.21% ± 0.18%
# 			AEK Athens: 8.10% ± 0.16%
# 			Crvena Zvezda: 7.83% ± 0.16%
# 			Lugano: 7.26% ± 0.16%
# 	Dynamo Kyiv
# 		Rivals in pot 2
# 			Marseille: 10.20% ± 0.17%
# 			Real Sociedad: 9.95% ± 0.18%
# 			Everton: 9.92% ± 0.20%
# 			Austria Wien: 9.88% ± 0.19%
# 			Nice: 9.09% ± 0.20%
# 			Ludogorets Razgrad: 8.63% ± 0.15%
# 			Maccabi Tel-Aviv: 8.58% ± 0.16%
# 			Hertha Berlin: 8.49% ± 0.16%
# 			Young Boys: 8.46% ± 0.17%
# 			BATE Borisov: 8.46% ± 0.17%
# 			FCSB: 8.33% ± 0.16%
# 		Rivals in pot 3
# 			Atalanta: 11.06% ± 0.22%
# 			Astana: 9.31% ± 0.17%
# 			Sheriff Tiraspol: 9.23% ± 0.17%
# 			Zulte Waregem: 9.13% ± 0.17%
# 			Rosenborg: 9.09% ± 0.19%
# 			Partizan: 9.05% ± 0.20%
# 			Rijeka: 8.98% ± 0.18%
# 			Köln: 8.90% ± 0.20%
# 			Vitória SC: 8.71% ± 0.17%
# 			Hoffenheim: 8.28% ± 0.18%
# 			Hapoel Beer-Sheva: 8.26% ± 0.17%
# 		Rivals in pot 4
# 			Zlín: 9.30% ± 0.17%
# 			Slavia Praha: 8.81% ± 0.16%
# 			Konyaspor: 8.45% ± 0.18%
# 			AEK Athens: 8.39% ± 0.15%
# 			Vitesse: 8.37% ± 0.18%
# 			Skënderbeu: 8.35% ± 0.16%
# 			Östersund: 8.31% ± 0.18%
# 			Apollon Limassol: 8.30% ± 0.17%
# 			Vardar: 8.23% ± 0.17%
# 			İstanbul Başakşehir: 8.19% ± 0.18%
# 			Lugano: 8.18% ± 0.19%
# 			Crvena Zvezda: 7.12% ± 0.17%
# Clubs in pot 2
# 	Austria Wien
# 		Rivals in pot 1
# 			Dynamo Kyiv: 9.88% ± 0.19%
# 			Athletic Club: 9.70% ± 0.21%
# 			Villarreal: 9.62% ± 0.18%
# 			Lyon: 9.38% ± 0.20%
# 			AC Milan: 9.28% ± 0.18%
# 			Lazio: 8.94% ± 0.16%
# 			København: 8.77% ± 0.17%
# 			Zenit: 8.71% ± 0.18%
# 			Viktoria Plzeň: 8.62% ± 0.16%
# 			Braga: 8.60% ± 0.18%
# 			Arsenal: 8.49% ± 0.18%
# 		Rivals in pot 3
# 			Hoffenheim: 11.62% ± 0.19%
# 			Hapoel Beer-Sheva: 11.47% ± 0.20%
# 			Zorya Luhansk: 10.58% ± 0.18%
# 			Vitória SC: 9.52% ± 0.18%
# 			Köln: 7.82% ± 0.17%
# 			Atalanta: 7.15% ± 0.17%
# 			Astana: 7.10% ± 0.16%
# 			Partizan: 7.02% ± 0.17%
# 			Zulte Waregem: 6.96% ± 0.17%
# 			Rijeka: 6.95% ± 0.15%
# 			Rosenborg: 6.95% ± 0.15%
# 			Sheriff Tiraspol: 6.86% ± 0.16%
# 		Rivals in pot 4
# 			Lugano: 12.01% ± 0.22%
# 			Crvena Zvezda: 11.15% ± 0.20%
# 			Slavia Praha: 9.80% ± 0.21%
# 			Konyaspor: 8.10% ± 0.19%
# 			İstanbul Başakşehir: 7.92% ± 0.16%
# 			Skënderbeu: 7.35% ± 0.17%
# 			Östersund: 7.34% ± 0.17%
# 			Zlín: 7.32% ± 0.15%
# 			AEK Athens: 7.30% ± 0.16%
# 			Vardar: 7.29% ± 0.16%
# 			Vitesse: 7.24% ± 0.16%
# 			Apollon Limassol: 7.18% ± 0.16%
# 	BATE Borisov
# 		Rivals in pot 1
# 			Lyon: 9.92% ± 0.20%
# 			Salzburg: 8.92% ± 0.19%
# 			Arsenal: 8.90% ± 0.19%
# 			Zenit: 8.81% ± 0.17%
# 			Villarreal: 8.46% ± 0.18%
# 			Dynamo Kyiv: 8.46% ± 0.17%
# 			Athletic Club: 8.37% ± 0.18%
# 			København: 7.79% ± 0.14%
# 			Viktoria Plzeň: 7.76% ± 0.15%
# 			Lazio: 7.67% ± 0.17%
# 			Braga: 7.63% ± 0.18%
# 			AC Milan: 7.31% ± 0.15%
# 		Rivals in pot 3
# 			Köln: 9.43% ± 0.16%
# 			Atalanta: 8.72% ± 0.17%
# 			Rosenborg: 8.69% ± 0.16%
# 			Rijeka: 8.55% ± 0.16%
# 			Partizan: 8.50% ± 0.16%
# 			Zorya Luhansk: 8.46% ± 0.17%
# 			Sheriff Tiraspol: 8.44% ± 0.15%
# 			Astana: 8.43% ± 0.17%
# 			Zulte Waregem: 8.34% ± 0.20%
# 			Vitória SC: 7.56% ± 0.17%
# 			Hapoel Beer-Sheva: 7.44% ± 0.19%
# 			Hoffenheim: 7.43% ± 0.16%
# 		Rivals in pot 4
# 			Vitesse: 8.83% ± 0.17%
# 			Skënderbeu: 8.77% ± 0.19%
# 			Östersund: 8.73% ± 0.17%
# 			Vardar: 8.69% ± 0.17%
# 			AEK Athens: 8.64% ± 0.17%
# 			Apollon Limassol: 8.62% ± 0.17%
# 			Zlín: 8.62% ± 0.16%
# 			Konyaspor: 8.50% ± 0.16%
# 			İstanbul Başakşehir: 8.47% ± 0.16%
# 			Slavia Praha: 7.61% ± 0.17%
# 			Lugano: 7.36% ± 0.16%
# 			Crvena Zvezda: 7.16% ± 0.17%
# 	Ludogorets Razgrad
# 		Rivals in pot 1
# 			Lyon: 9.68% ± 0.16%
# 			Zenit: 8.99% ± 0.19%
# 			Salzburg: 8.85% ± 0.18%
# 			Arsenal: 8.84% ± 0.20%
# 			Dynamo Kyiv: 8.63% ± 0.15%
# 			Athletic Club: 8.47% ± 0.19%
# 			Villarreal: 8.34% ± 0.17%
# 			Lazio: 7.79% ± 0.18%
# 			Braga: 7.75% ± 0.18%
# 			Viktoria Plzeň: 7.66% ± 0.17%
# 			København: 7.53% ± 0.15%
# 			AC Milan: 7.46% ± 0.17%
# 		Rivals in pot 3
# 			Köln: 9.62% ± 0.17%
# 			Atalanta: 8.65% ± 0.18%
# 			Zorya Luhansk: 8.59% ± 0.19%
# 			Partizan: 8.57% ± 0.20%
# 			Astana: 8.53% ± 0.18%
# 			Rijeka: 8.47% ± 0.18%
# 			Zulte Waregem: 8.46% ± 0.18%
# 			Sheriff Tiraspol: 8.37% ± 0.16%
# 			Rosenborg: 8.32% ± 0.16%
# 			Vitória SC: 7.52% ± 0.19%
# 			Hoffenheim: 7.49% ± 0.15%
# 			Hapoel Beer-Sheva: 7.41% ± 0.15%
# 		Rivals in pot 4
# 			Zlín: 8.84% ± 0.17%
# 			Skënderbeu: 8.67% ± 0.18%
# 			Apollon Limassol: 8.66% ± 0.20%
# 			Konyaspor: 8.62% ± 0.19%
# 			Östersund: 8.62% ± 0.20%
# 			AEK Athens: 8.61% ± 0.17%
# 			Vitesse: 8.60% ± 0.19%
# 			Vardar: 8.59% ± 0.17%
# 			İstanbul Başakşehir: 8.50% ± 0.17%
# 			Slavia Praha: 7.56% ± 0.15%
# 			Lugano: 7.51% ± 0.16%
# 			Crvena Zvezda: 7.23% ± 0.18%
# 	Everton
# 		Rivals in pot 1
# 			Dynamo Kyiv: 9.92% ± 0.20%
# 			Athletic Club: 9.77% ± 0.19%
# 			Villarreal: 9.67% ± 0.17%
# 			Lyon: 9.37% ± 0.17%
# 			AC Milan: 9.16% ± 0.19%
# 			Lazio: 9.15% ± 0.17%
# 			Viktoria Plzeň: 8.70% ± 0.19%
# 			København: 8.60% ± 0.17%
# 			Zenit: 8.59% ± 0.17%
# 			Braga: 8.56% ± 0.19%
# 			Salzburg: 8.52% ± 0.18%
# 		Rivals in pot 3
# 			Hoffenheim: 11.47% ± 0.22%
# 			Hapoel Beer-Sheva: 11.38% ± 0.21%
# 			Zorya Luhansk: 10.64% ± 0.19%
# 			Vitória SC: 9.49% ± 0.20%
# 			Köln: 7.88% ± 0.17%
# 			Rijeka: 7.15% ± 0.19%
# 			Astana: 7.10% ± 0.17%
# 			Zulte Waregem: 7.05% ± 0.14%
# 			Rosenborg: 7.04% ± 0.16%
# 			Sheriff Tiraspol: 6.96% ± 0.15%
# 			Partizan: 6.94% ± 0.15%
# 			Atalanta: 6.89% ± 0.16%
# 		Rivals in pot 4
# 			Lugano: 12.07% ± 0.18%
# 			Crvena Zvezda: 11.07% ± 0.17%
# 			Slavia Praha: 9.79% ± 0.20%
# 			İstanbul Başakşehir: 8.12% ± 0.17%
# 			Konyaspor: 7.92% ± 0.17%
# 			AEK Athens: 7.42% ± 0.14%
# 			Skënderbeu: 7.35% ± 0.18%
# 			Apollon Limassol: 7.35% ± 0.16%
# 			Östersund: 7.29% ± 0.16%
# 			Vardar: 7.23% ± 0.19%
# 			Zlín: 7.21% ± 0.16%
# 			Vitesse: 7.18% ± 0.17%
# 	Real Sociedad
# 		Rivals in pot 1
# 			Lyon: 11.63% ± 0.21%
# 			Zenit: 10.70% ± 0.18%
# 			Salzburg: 10.54% ± 0.20%
# 			Arsenal: 10.49% ± 0.19%
# 			Dynamo Kyiv: 9.95% ± 0.18%
# 			Braga: 9.52% ± 0.19%
# 			København: 9.47% ± 0.20%
# 			AC Milan: 9.26% ± 0.16%
# 			Viktoria Plzeň: 9.25% ± 0.19%
# 			Lazio: 9.20% ± 0.20%
# 		Rivals in pot 3
# 			Köln: 9.73% ± 0.18%
# 			Rosenborg: 8.66% ± 0.17%
# 			Zulte Waregem: 8.66% ± 0.16%
# 			Astana: 8.63% ± 0.16%
# 			Sheriff Tiraspol: 8.62% ± 0.18%
# 			Partizan: 8.58% ± 0.19%
# 			Rijeka: 8.47% ± 0.17%
# 			Atalanta: 8.42% ± 0.18%
# 			Zorya Luhansk: 8.12% ± 0.16%
# 			Hoffenheim: 7.49% ± 0.17%
# 			Vitória SC: 7.34% ± 0.16%
# 			Hapoel Beer-Sheva: 7.28% ± 0.16%
# 		Rivals in pot 4
# 			Vardar: 8.87% ± 0.18%
# 			Vitesse: 8.87% ± 0.17%
# 			AEK Athens: 8.76% ± 0.19%
# 			Skënderbeu: 8.66% ± 0.19%
# 			Apollon Limassol: 8.65% ± 0.18%
# 			Zlín: 8.54% ± 0.18%
# 			İstanbul Başakşehir: 8.50% ± 0.18%
# 			Östersund: 8.46% ± 0.18%
# 			Konyaspor: 8.45% ± 0.19%
# 			Slavia Praha: 7.48% ± 0.16%
# 			Lugano: 7.45% ± 0.15%
# 			Crvena Zvezda: 7.32% ± 0.15%
# 	Marseille
# 		Rivals in pot 1
# 			Dynamo Kyiv: 10.20% ± 0.17%
# 			Villarreal: 9.95% ± 0.17%
# 			Athletic Club: 9.76% ± 0.17%
# 			Lazio: 9.16% ± 0.17%
# 			AC Milan: 9.15% ± 0.16%
# 			Viktoria Plzeň: 8.78% ± 0.18%
# 			Braga: 8.77% ± 0.18%
# 			Zenit: 8.71% ± 0.18%
# 			Arsenal: 8.57% ± 0.16%
# 			København: 8.52% ± 0.17%
# 			Salzburg: 8.45% ± 0.20%
# 		Rivals in pot 3
# 			Hoffenheim: 11.70% ± 0.21%
# 			Hapoel Beer-Sheva: 11.58% ± 0.22%
# 			Zorya Luhansk: 10.40% ± 0.19%
# 			Vitória SC: 9.59% ± 0.18%
# 			Köln: 7.56% ± 0.16%
# 			Sheriff Tiraspol: 7.14% ± 0.15%
# 			Rosenborg: 7.10% ± 0.16%
# 			Atalanta: 7.05% ± 0.18%
# 			Partizan: 7.02% ± 0.17%
# 			Zulte Waregem: 6.99% ± 0.15%
# 			Rijeka: 6.94% ± 0.16%
# 			Astana: 6.93% ± 0.15%
# 		Rivals in pot 4
# 			Lugano: 11.78% ± 0.21%
# 			Crvena Zvezda: 11.05% ± 0.21%
# 			Slavia Praha: 9.82% ± 0.20%
# 			İstanbul Başakşehir: 8.10% ± 0.17%
# 			Konyaspor: 8.07% ± 0.16%
# 			Skënderbeu: 7.39% ± 0.15%
# 			Östersund: 7.36% ± 0.18%
# 			Zlín: 7.34% ± 0.17%
# 			Vardar: 7.33% ± 0.19%
# 			Apollon Limassol: 7.29% ± 0.16%
# 			AEK Athens: 7.28% ± 0.17%
# 			Vitesse: 7.20% ± 0.16%
# 	Nice
# 		Rivals in pot 1
# 			Zenit: 9.96% ± 0.19%
# 			Arsenal: 9.79% ± 0.17%
# 			Salzburg: 9.73% ± 0.24%
# 			Villarreal: 9.33% ± 0.17%
# 			Athletic Club: 9.33% ± 0.22%
# 			Dynamo Kyiv: 9.09% ± 0.20%
# 			Braga: 8.61% ± 0.18%
# 			Viktoria Plzeň: 8.56% ± 0.16%
# 			AC Milan: 8.56% ± 0.16%
# 			Lazio: 8.55% ± 0.20%
# 			København: 8.51% ± 0.17%
# 		Rivals in pot 3
# 			Köln: 9.56% ± 0.20%
# 			Astana: 8.63% ± 0.18%
# 			Partizan: 8.59% ± 0.19%
# 			Rosenborg: 8.54% ± 0.16%
# 			Zulte Waregem: 8.47% ± 0.19%
# 			Zorya Luhansk: 8.45% ± 0.19%
# 			Sheriff Tiraspol: 8.44% ± 0.17%
# 			Atalanta: 8.33% ± 0.17%
# 			Rijeka: 8.29% ± 0.18%
# 			Vitória SC: 7.68% ± 0.16%
# 			Hoffenheim: 7.60% ± 0.16%
# 			Hapoel Beer-Sheva: 7.41% ± 0.14%
# 		Rivals in pot 4
# 			AEK Athens: 8.75% ± 0.18%
# 			Skënderbeu: 8.72% ± 0.15%
# 			Vitesse: 8.68% ± 0.15%
# 			Zlín: 8.67% ± 0.18%
# 			Östersund: 8.63% ± 0.18%
# 			Vardar: 8.63% ± 0.16%
# 			Apollon Limassol: 8.56% ± 0.18%
# 			Konyaspor: 8.41% ± 0.18%
# 			İstanbul Başakşehir: 8.35% ± 0.17%
# 			Slavia Praha: 7.76% ± 0.17%
# 			Lugano: 7.50% ± 0.15%
# 			Crvena Zvezda: 7.34% ± 0.17%
# 	Hertha Berlin
# 		Rivals in pot 1
# 			Lyon: 10.13% ± 0.21%
# 			Arsenal: 9.12% ± 0.16%
# 			Salzburg: 8.87% ± 0.19%
# 			Zenit: 8.85% ± 0.20%
# 			Dynamo Kyiv: 8.49% ± 0.16%
# 			Athletic Club: 8.45% ± 0.16%
# 			Villarreal: 8.23% ± 0.16%
# 			København: 7.69% ± 0.17%
# 			Viktoria Plzeň: 7.67% ± 0.16%
# 			Braga: 7.60% ± 0.15%
# 			Lazio: 7.47% ± 0.17%
# 			AC Milan: 7.43% ± 0.17%
# 		Rivals in pot 3
# 			Rijeka: 10.83% ± 0.18%
# 			Sheriff Tiraspol: 10.75% ± 0.20%
# 			Zulte Waregem: 10.72% ± 0.20%
# 			Rosenborg: 10.64% ± 0.21%
# 			Astana: 10.64% ± 0.18%
# 			Partizan: 10.51% ± 0.17%
# 			Atalanta: 10.44% ± 0.21%
# 			Zorya Luhansk: 9.19% ± 0.17%
# 			Vitória SC: 8.29% ± 0.18%
# 			Hapoel Beer-Sheva: 8.00% ± 0.17%
# 		Rivals in pot 4
# 			Apollon Limassol: 9.06% ± 0.20%
# 			Zlín: 8.87% ± 0.17%
# 			Östersund: 8.85% ± 0.19%
# 			Vitesse: 8.85% ± 0.19%
# 			AEK Athens: 8.71% ± 0.16%
# 			Vardar: 8.67% ± 0.18%
# 			İstanbul Başakşehir: 8.62% ± 0.16%
# 			Skënderbeu: 8.61% ± 0.18%
# 			Konyaspor: 8.42% ± 0.18%
# 			Slavia Praha: 7.59% ± 0.16%
# 			Lugano: 7.51% ± 0.17%
# 			Crvena Zvezda: 6.22% ± 0.14%
# 	Maccabi Tel-Aviv
# 		Rivals in pot 1
# 			Lyon: 9.88% ± 0.20%
# 			Zenit: 8.90% ± 0.20%
# 			Salzburg: 8.87% ± 0.20%
# 			Arsenal: 8.86% ± 0.18%
# 			Dynamo Kyiv: 8.58% ± 0.16%
# 			Villarreal: 8.48% ± 0.18%
# 			Athletic Club: 8.44% ± 0.16%
# 			København: 7.80% ± 0.16%
# 			Viktoria Plzeň: 7.74% ± 0.15%
# 			Braga: 7.72% ± 0.16%
# 			Lazio: 7.42% ± 0.14%
# 			AC Milan: 7.31% ± 0.16%
# 		Rivals in pot 3
# 			Köln: 10.62% ± 0.18%
# 			Rijeka: 9.62% ± 0.16%
# 			Zulte Waregem: 9.60% ± 0.19%
# 			Atalanta: 9.56% ± 0.18%
# 			Sheriff Tiraspol: 9.54% ± 0.19%
# 			Partizan: 9.45% ± 0.20%
# 			Astana: 9.32% ± 0.18%
# 			Rosenborg: 9.29% ± 0.16%
# 			Zorya Luhansk: 8.54% ± 0.17%
# 			Vitória SC: 7.24% ± 0.15%
# 			Hoffenheim: 7.22% ± 0.18%
# 		Rivals in pot 4
# 			Zlín: 8.94% ± 0.19%
# 			Vardar: 8.89% ± 0.17%
# 			Apollon Limassol: 8.88% ± 0.19%
# 			Skënderbeu: 8.82% ± 0.18%
# 			AEK Athens: 8.79% ± 0.19%
# 			Östersund: 8.75% ± 0.20%
# 			Vitesse: 8.68% ± 0.16%
# 			İstanbul Başakşehir: 8.48% ± 0.16%
# 			Konyaspor: 8.48% ± 0.19%
# 			Slavia Praha: 7.69% ± 0.16%
# 			Lugano: 7.46% ± 0.17%
# 			Crvena Zvezda: 6.14% ± 0.14%
# 	FCSB
# 		Rivals in pot 1
# 			Lyon: 9.86% ± 0.19%
# 			Arsenal: 8.87% ± 0.19%
# 			Zenit: 8.80% ± 0.17%
# 			Salzburg: 8.78% ± 0.19%
# 			Villarreal: 8.69% ± 0.17%
# 			Athletic Club: 8.50% ± 0.19%
# 			Dynamo Kyiv: 8.33% ± 0.16%
# 			Braga: 7.90% ± 0.17%
# 			København: 7.75% ± 0.16%
# 			Viktoria Plzeň: 7.65% ± 0.15%
# 			AC Milan: 7.59% ± 0.17%
# 			Lazio: 7.28% ± 0.17%
# 		Rivals in pot 3
# 			Köln: 9.61% ± 0.18%
# 			Atalanta: 8.72% ± 0.18%
# 			Zorya Luhansk: 8.64% ± 0.19%
# 			Sheriff Tiraspol: 8.51% ± 0.18%
# 			Partizan: 8.47% ± 0.16%
# 			Rosenborg: 8.46% ± 0.16%
# 			Zulte Waregem: 8.45% ± 0.18%
# 			Rijeka: 8.45% ± 0.16%
# 			Astana: 8.30% ± 0.18%
# 			Vitória SC: 7.58% ± 0.18%
# 			Hoffenheim: 7.41% ± 0.17%
# 			Hapoel Beer-Sheva: 7.41% ± 0.19%
# 		Rivals in pot 4
# 			Zlín: 8.78% ± 0.20%
# 			Vitesse: 8.73% ± 0.17%
# 			Vardar: 8.70% ± 0.18%
# 			Apollon Limassol: 8.65% ± 0.19%
# 			Östersund: 8.64% ± 0.16%
# 			AEK Athens: 8.55% ± 0.19%
# 			Skënderbeu: 8.55% ± 0.17%
# 			Konyaspor: 8.52% ± 0.19%
# 			İstanbul Başakşehir: 8.48% ± 0.17%
# 			Slavia Praha: 7.75% ± 0.18%
# 			Lugano: 7.42% ± 0.16%
# 			Crvena Zvezda: 7.24% ± 0.19%
# 	Lokomotiv Moscow
# 		Rivals in pot 1
# 			Villarreal: 10.75% ± 0.19%
# 			Athletic Club: 10.68% ± 0.18%
# 			Lyon: 10.23% ± 0.20%
# 			Lazio: 10.09% ± 0.19%
# 			AC Milan: 10.00% ± 0.21%
# 			Viktoria Plzeň: 9.79% ± 0.18%
# 			København: 9.77% ± 0.19%
# 			Braga: 9.72% ± 0.17%
# 			Salzburg: 9.64% ± 0.16%
# 			Arsenal: 9.31% ± 0.17%
# 		Rivals in pot 3
# 			Hapoel Beer-Sheva: 13.29% ± 0.22%
# 			Hoffenheim: 13.16% ± 0.23%
# 			Vitória SC: 10.66% ± 0.19%
# 			Köln: 8.57% ± 0.18%
# 			Zulte Waregem: 7.87% ± 0.18%
# 			Sheriff Tiraspol: 7.85% ± 0.16%
# 			Partizan: 7.85% ± 0.18%
# 			Astana: 7.83% ± 0.18%
# 			Rosenborg: 7.83% ± 0.17%
# 			Rijeka: 7.80% ± 0.19%
# 			Atalanta: 7.30% ± 0.15%
# 		Rivals in pot 4
# 			Lugano: 11.94% ± 0.20%
# 			Crvena Zvezda: 10.93% ± 0.19%
# 			Slavia Praha: 9.65% ± 0.19%
# 			İstanbul Başakşehir: 8.09% ± 0.17%
# 			Konyaspor: 8.03% ± 0.17%
# 			AEK Athens: 7.44% ± 0.17%
# 			Östersund: 7.41% ± 0.15%
# 			Vitesse: 7.37% ± 0.16%
# 			Apollon Limassol: 7.37% ± 0.17%
# 			Skënderbeu: 7.35% ± 0.17%
# 			Vardar: 7.35% ± 0.18%
# 			Zlín: 7.08% ± 0.15%
# 	Young Boys
# 		Rivals in pot 1
# 			Lyon: 9.92% ± 0.19%
# 			Zenit: 8.98% ± 0.21%
# 			Salzburg: 8.85% ± 0.19%
# 			Arsenal: 8.76% ± 0.19%
# 			Athletic Club: 8.54% ± 0.18%
# 			Villarreal: 8.47% ± 0.18%
# 			Dynamo Kyiv: 8.46% ± 0.17%
# 			Viktoria Plzeň: 7.81% ± 0.16%
# 			København: 7.81% ± 0.18%
# 			Braga: 7.63% ± 0.17%
# 			AC Milan: 7.48% ± 0.17%
# 			Lazio: 7.30% ± 0.14%
# 		Rivals in pot 3
# 			Köln: 9.60% ± 0.19%
# 			Atalanta: 8.77% ± 0.18%
# 			Astana: 8.57% ± 0.17%
# 			Sheriff Tiraspol: 8.53% ± 0.18%
# 			Partizan: 8.50% ± 0.17%
# 			Rosenborg: 8.49% ± 0.20%
# 			Rijeka: 8.47% ± 0.15%
# 			Zulte Waregem: 8.43% ± 0.17%
# 			Zorya Luhansk: 8.39% ± 0.17%
# 			Vitória SC: 7.51% ± 0.16%
# 			Hoffenheim: 7.42% ± 0.15%
# 			Hapoel Beer-Sheva: 7.33% ± 0.17%
# 		Rivals in pot 4
# 			Östersund: 9.92% ± 0.18%
# 			Zlín: 9.80% ± 0.20%
# 			Vitesse: 9.79% ± 0.17%
# 			Vardar: 9.77% ± 0.18%
# 			Skënderbeu: 9.77% ± 0.18%
# 			Apollon Limassol: 9.74% ± 0.17%
# 			AEK Athens: 9.73% ± 0.20%
# 			Konyaspor: 8.47% ± 0.17%
# 			İstanbul Başakşehir: 8.36% ± 0.17%
# 			Slavia Praha: 7.51% ± 0.16%
# 			Crvena Zvezda: 7.15% ± 0.18%
# Clubs in pot 3
# 	Zulte Waregem
# 		Rivals in pot 1
# 			Dynamo Kyiv: 9.13% ± 0.17%
# 			Zenit: 9.02% ± 0.18%
# 			Braga: 8.86% ± 0.17%
# 			Lazio: 8.74% ± 0.17%
# 			AC Milan: 8.50% ± 0.19%
# 			Arsenal: 8.27% ± 0.18%
# 			Salzburg: 8.25% ± 0.16%
# 			Lyon: 8.18% ± 0.18%
# 			København: 8.01% ± 0.19%
# 			Viktoria Plzeň: 7.99% ± 0.18%
# 			Athletic Club: 7.54% ± 0.19%
# 			Villarreal: 7.51% ± 0.16%
# 		Rivals in pot 2
# 			Hertha Berlin: 10.72% ± 0.20%
# 			Maccabi Tel-Aviv: 9.60% ± 0.19%
# 			Real Sociedad: 8.66% ± 0.16%
# 			Nice: 8.47% ± 0.19%
# 			Ludogorets Razgrad: 8.46% ± 0.18%
# 			FCSB: 8.45% ± 0.18%
# 			Young Boys: 8.43% ± 0.17%
# 			BATE Borisov: 8.34% ± 0.20%
# 			Lokomotiv Moscow: 7.87% ± 0.18%
# 			Everton: 7.05% ± 0.14%
# 			Marseille: 6.99% ± 0.15%
# 			Austria Wien: 6.96% ± 0.17%
# 		Rivals in pot 4
# 			Östersund: 8.79% ± 0.16%
# 			Vitesse: 8.70% ± 0.17%
# 			Zlín: 8.69% ± 0.17%
# 			Apollon Limassol: 8.67% ± 0.16%
# 			AEK Athens: 8.60% ± 0.16%
# 			Skënderbeu: 8.60% ± 0.16%
# 			İstanbul Başakşehir: 8.56% ± 0.17%
# 			Vardar: 8.51% ± 0.19%
# 			Konyaspor: 8.34% ± 0.16%
# 			Slavia Praha: 7.62% ± 0.17%
# 			Crvena Zvezda: 7.47% ± 0.17%
# 			Lugano: 7.44% ± 0.15%
# 	Rijeka
# 		Rivals in pot 1
# 			Braga: 9.18% ± 0.18%
# 			Dynamo Kyiv: 8.98% ± 0.18%
# 			Zenit: 8.91% ± 0.18%
# 			AC Milan: 8.56% ± 0.18%
# 			Lazio: 8.48% ± 0.17%
# 			Salzburg: 8.28% ± 0.18%
# 			Lyon: 8.23% ± 0.19%
# 			Arsenal: 8.09% ± 0.16%
# 			Viktoria Plzeň: 7.97% ± 0.17%
# 			København: 7.90% ± 0.16%
# 			Villarreal: 7.72% ± 0.15%
# 			Athletic Club: 7.69% ± 0.15%
# 		Rivals in pot 2
# 			Hertha Berlin: 10.83% ± 0.18%
# 			Maccabi Tel-Aviv: 9.62% ± 0.16%
# 			BATE Borisov: 8.55% ± 0.16%
# 			Young Boys: 8.47% ± 0.15%
# 			Ludogorets Razgrad: 8.47% ± 0.18%
# 			Real Sociedad: 8.47% ± 0.17%
# 			FCSB: 8.45% ± 0.16%
# 			Nice: 8.29% ± 0.18%
# 			Lokomotiv Moscow: 7.80% ± 0.19%
# 			Everton: 7.15% ± 0.19%
# 			Austria Wien: 6.95% ± 0.15%
# 			Marseille: 6.94% ± 0.16%
# 		Rivals in pot 4
# 			Skënderbeu: 8.76% ± 0.19%
# 			Vardar: 8.69% ± 0.16%
# 			Östersund: 8.66% ± 0.18%
# 			Vitesse: 8.64% ± 0.16%
# 			Zlín: 8.63% ± 0.19%
# 			AEK Athens: 8.62% ± 0.17%
# 			Apollon Limassol: 8.56% ± 0.16%
# 			İstanbul Başakşehir: 8.53% ± 0.17%
# 			Konyaspor: 8.44% ± 0.17%
# 			Slavia Praha: 7.65% ± 0.16%
# 			Crvena Zvezda: 7.40% ± 0.16%
# 			Lugano: 7.40% ± 0.16%
# 	Hoffenheim
# 		Rivals in pot 1
# 			Lazio: 9.98% ± 0.20%
# 			AC Milan: 9.88% ± 0.19%
# 			Athletic Club: 9.32% ± 0.19%
# 			Villarreal: 9.23% ± 0.18%
# 			Dynamo Kyiv: 8.28% ± 0.18%
# 			Zenit: 8.25% ± 0.17%
# 			København: 8.06% ± 0.19%
# 			Viktoria Plzeň: 8.05% ± 0.18%
# 			Braga: 7.99% ± 0.18%
# 			Arsenal: 7.01% ± 0.14%
# 			Lyon: 7.00% ± 0.14%
# 			Salzburg: 6.96% ± 0.16%
# 		Rivals in pot 2
# 			Lokomotiv Moscow: 13.16% ± 0.23%
# 			Marseille: 11.70% ± 0.21%
# 			Austria Wien: 11.62% ± 0.19%
# 			Everton: 11.47% ± 0.22%
# 			Nice: 7.60% ± 0.16%
# 			Real Sociedad: 7.49% ± 0.17%
# 			Ludogorets Razgrad: 7.49% ± 0.15%
# 			BATE Borisov: 7.43% ± 0.16%
# 			Young Boys: 7.42% ± 0.15%
# 			FCSB: 7.41% ± 0.17%
# 			Maccabi Tel-Aviv: 7.22% ± 0.18%
# 		Rivals in pot 4
# 			Crvena Zvezda: 12.21% ± 0.22%
# 			Slavia Praha: 10.61% ± 0.19%
# 			Lugano: 10.06% ± 0.18%
# 			Konyaspor: 8.13% ± 0.19%
# 			İstanbul Başakşehir: 8.00% ± 0.21%
# 			AEK Athens: 7.42% ± 0.17%
# 			Zlín: 7.37% ± 0.17%
# 			Vitesse: 7.30% ± 0.18%
# 			Skënderbeu: 7.25% ± 0.18%
# 			Vardar: 7.24% ± 0.17%
# 			Östersund: 7.22% ± 0.14%
# 			Apollon Limassol: 7.20% ± 0.14%
# 	Köln
# 		Rivals in pot 1
# 			Braga: 9.32% ± 0.18%
# 			Zenit: 8.93% ± 0.21%
# 			Dynamo Kyiv: 8.90% ± 0.20%
# 			Lazio: 8.56% ± 0.19%
# 			AC Milan: 8.47% ± 0.16%
# 			Salzburg: 8.22% ± 0.17%
# 			Arsenal: 8.15% ± 0.17%
# 			København: 8.13% ± 0.16%
# 			Lyon: 8.13% ± 0.17%
# 			Viktoria Plzeň: 8.01% ± 0.17%
# 			Athletic Club: 7.62% ± 0.14%
# 			Villarreal: 7.56% ± 0.16%
# 		Rivals in pot 2
# 			Maccabi Tel-Aviv: 10.62% ± 0.18%
# 			Real Sociedad: 9.73% ± 0.18%
# 			Ludogorets Razgrad: 9.62% ± 0.17%
# 			FCSB: 9.61% ± 0.18%
# 			Young Boys: 9.60% ± 0.19%
# 			Nice: 9.56% ± 0.20%
# 			BATE Borisov: 9.43% ± 0.16%
# 			Lokomotiv Moscow: 8.57% ± 0.18%
# 			Everton: 7.88% ± 0.17%
# 			Austria Wien: 7.82% ± 0.17%
# 			Marseille: 7.56% ± 0.16%
# 		Rivals in pot 4
# 			Skënderbeu: 8.85% ± 0.18%
# 			Vardar: 8.76% ± 0.19%
# 			Vitesse: 8.73% ± 0.18%
# 			Apollon Limassol: 8.72% ± 0.17%
# 			Zlín: 8.68% ± 0.20%
# 			AEK Athens: 8.66% ± 0.18%
# 			Östersund: 8.59% ± 0.16%
# 			Konyaspor: 8.50% ± 0.17%
# 			İstanbul Başakşehir: 8.23% ± 0.17%
# 			Slavia Praha: 7.49% ± 0.15%
# 			Crvena Zvezda: 7.49% ± 0.18%
# 			Lugano: 7.30% ± 0.16%
# 	Hapoel Beer-Sheva
# 		Rivals in pot 1
# 			AC Milan: 9.88% ± 0.19%
# 			Lazio: 9.81% ± 0.22%
# 			Athletic Club: 9.25% ± 0.18%
# 			Villarreal: 9.13% ± 0.20%
# 			Dynamo Kyiv: 8.26% ± 0.17%
# 			Viktoria Plzeň: 8.26% ± 0.18%
# 			Zenit: 8.25% ± 0.16%
# 			København: 8.07% ± 0.17%
# 			Braga: 8.00% ± 0.16%
# 			Salzburg: 7.14% ± 0.17%
# 			Lyon: 6.99% ± 0.17%
# 			Arsenal: 6.96% ± 0.14%
# 		Rivals in pot 2
# 			Lokomotiv Moscow: 13.29% ± 0.22%
# 			Marseille: 11.58% ± 0.22%
# 			Austria Wien: 11.47% ± 0.20%
# 			Everton: 11.38% ± 0.21%
# 			Hertha Berlin: 8.00% ± 0.17%
# 			BATE Borisov: 7.44% ± 0.19%
# 			Ludogorets Razgrad: 7.41% ± 0.15%
# 			Nice: 7.41% ± 0.14%
# 			FCSB: 7.41% ± 0.19%
# 			Young Boys: 7.33% ± 0.17%
# 			Real Sociedad: 7.28% ± 0.16%
# 		Rivals in pot 4
# 			Crvena Zvezda: 12.26% ± 0.20%
# 			Slavia Praha: 10.53% ± 0.20%
# 			Lugano: 10.15% ± 0.17%
# 			Konyaspor: 8.09% ± 0.17%
# 			İstanbul Başakşehir: 7.97% ± 0.17%
# 			Östersund: 7.43% ± 0.17%
# 			Skënderbeu: 7.32% ± 0.15%
# 			Zlín: 7.30% ± 0.16%
# 			Apollon Limassol: 7.29% ± 0.19%
# 			Vardar: 7.25% ± 0.15%
# 			Vitesse: 7.25% ± 0.16%
# 			AEK Athens: 7.15% ± 0.16%
# 	Atalanta
# 		Rivals in pot 1
# 			Dynamo Kyiv: 11.06% ± 0.22%
# 			Braga: 10.83% ± 0.16%
# 			Zenit: 10.55% ± 0.21%
# 			Salzburg: 9.99% ± 0.22%
# 			Arsenal: 9.87% ± 0.19%
# 			Lyon: 9.70% ± 0.17%
# 			Viktoria Plzeň: 9.68% ± 0.21%
# 			København: 9.60% ± 0.19%
# 			Villarreal: 9.38% ± 0.16%
# 			Athletic Club: 9.34% ± 0.18%
# 		Rivals in pot 2
# 			Hertha Berlin: 10.44% ± 0.21%
# 			Maccabi Tel-Aviv: 9.56% ± 0.18%
# 			Young Boys: 8.77% ± 0.18%
# 			FCSB: 8.72% ± 0.18%
# 			BATE Borisov: 8.72% ± 0.17%
# 			Ludogorets Razgrad: 8.65% ± 0.18%
# 			Real Sociedad: 8.42% ± 0.18%
# 			Nice: 8.33% ± 0.17%
# 			Lokomotiv Moscow: 7.30% ± 0.15%
# 			Austria Wien: 7.15% ± 0.17%
# 			Marseille: 7.05% ± 0.18%
# 			Everton: 6.89% ± 0.16%
# 		Rivals in pot 4
# 			Vitesse: 8.81% ± 0.19%
# 			AEK Athens: 8.79% ± 0.17%
# 			Östersund: 8.75% ± 0.19%
# 			Skënderbeu: 8.74% ± 0.18%
# 			Apollon Limassol: 8.69% ± 0.14%
# 			Vardar: 8.68% ± 0.16%
# 			İstanbul Başakşehir: 8.61% ± 0.19%
# 			Zlín: 8.59% ± 0.17%
# 			Konyaspor: 8.35% ± 0.17%
# 			Crvena Zvezda: 7.39% ± 0.15%
# 			Lugano: 7.37% ± 0.15%
# 			Slavia Praha: 7.24% ± 0.16%
# 	Astana
# 		Rivals in pot 1
# 			Dynamo Kyiv: 9.31% ± 0.17%
# 			Zenit: 9.12% ± 0.18%
# 			Braga: 8.96% ± 0.18%
# 			AC Milan: 8.68% ± 0.19%
# 			Lazio: 8.43% ± 0.16%
# 			Lyon: 8.24% ± 0.17%
# 			Salzburg: 8.18% ± 0.19%
# 			Arsenal: 8.06% ± 0.16%
# 			Viktoria Plzeň: 7.97% ± 0.18%
# 			København: 7.85% ± 0.18%
# 			Villarreal: 7.62% ± 0.16%
# 			Athletic Club: 7.58% ± 0.17%
# 		Rivals in pot 2
# 			Hertha Berlin: 10.64% ± 0.18%
# 			Maccabi Tel-Aviv: 9.32% ± 0.18%
# 			Real Sociedad: 8.63% ± 0.16%
# 			Nice: 8.63% ± 0.18%
# 			Young Boys: 8.57% ± 0.17%
# 			Ludogorets Razgrad: 8.53% ± 0.18%
# 			BATE Borisov: 8.43% ± 0.17%
# 			FCSB: 8.30% ± 0.18%
# 			Lokomotiv Moscow: 7.83% ± 0.18%
# 			Austria Wien: 7.10% ± 0.16%
# 			Everton: 7.10% ± 0.17%
# 			Marseille: 6.93% ± 0.15%
# 		Rivals in pot 4
# 			Skënderbeu: 8.75% ± 0.18%
# 			AEK Athens: 8.73% ± 0.19%
# 			Apollon Limassol: 8.66% ± 0.18%
# 			Vitesse: 8.65% ± 0.18%
# 			Östersund: 8.63% ± 0.17%
# 			Zlín: 8.62% ± 0.19%
# 			Vardar: 8.57% ± 0.18%
# 			İstanbul Başakşehir: 8.49% ± 0.19%
# 			Konyaspor: 8.42% ± 0.15%
# 			Slavia Praha: 7.63% ± 0.16%
# 			Lugano: 7.47% ± 0.18%
# 			Crvena Zvezda: 7.38% ± 0.16%
# 	Sheriff Tiraspol
# 		Rivals in pot 1
# 			Dynamo Kyiv: 9.23% ± 0.17%
# 			Braga: 9.04% ± 0.19%
# 			Zenit: 8.91% ± 0.17%
# 			AC Milan: 8.61% ± 0.16%
# 			Lazio: 8.50% ± 0.18%
# 			Arsenal: 8.28% ± 0.19%
# 			Lyon: 8.20% ± 0.16%
# 			Salzburg: 8.15% ± 0.17%
# 			København: 7.99% ± 0.16%
# 			Viktoria Plzeň: 7.85% ± 0.15%
# 			Villarreal: 7.68% ± 0.20%
# 			Athletic Club: 7.58% ± 0.17%
# 		Rivals in pot 2
# 			Hertha Berlin: 10.75% ± 0.20%
# 			Maccabi Tel-Aviv: 9.54% ± 0.19%
# 			Real Sociedad: 8.62% ± 0.18%
# 			Young Boys: 8.53% ± 0.18%
# 			FCSB: 8.51% ± 0.18%
# 			Nice: 8.44% ± 0.17%
# 			BATE Borisov: 8.44% ± 0.15%
# 			Ludogorets Razgrad: 8.37% ± 0.16%
# 			Lokomotiv Moscow: 7.85% ± 0.16%
# 			Marseille: 7.14% ± 0.15%
# 			Everton: 6.96% ± 0.15%
# 			Austria Wien: 6.86% ± 0.16%
# 		Rivals in pot 4
# 			Zlín: 8.75% ± 0.17%
# 			Skënderbeu: 8.72% ± 0.17%
# 			Apollon Limassol: 8.72% ± 0.17%
# 			Vardar: 8.72% ± 0.19%
# 			Vitesse: 8.70% ± 0.18%
# 			AEK Athens: 8.69% ± 0.19%
# 			Östersund: 8.64% ± 0.18%
# 			İstanbul Başakşehir: 8.47% ± 0.17%
# 			Konyaspor: 8.36% ± 0.17%
# 			Lugano: 7.52% ± 0.17%
# 			Slavia Praha: 7.40% ± 0.18%
# 			Crvena Zvezda: 7.31% ± 0.16%
# 	Rosenborg
# 		Rivals in pot 1
# 			Dynamo Kyiv: 9.09% ± 0.19%
# 			Braga: 9.01% ± 0.19%
# 			Zenit: 8.97% ± 0.16%
# 			AC Milan: 8.77% ± 0.17%
# 			Lazio: 8.56% ± 0.18%
# 			Arsenal: 8.31% ± 0.16%
# 			Lyon: 8.31% ± 0.18%
# 			Salzburg: 8.28% ± 0.18%
# 			Viktoria Plzeň: 7.94% ± 0.18%
# 			København: 7.91% ± 0.17%
# 			Villarreal: 7.48% ± 0.16%
# 			Athletic Club: 7.38% ± 0.18%
# 		Rivals in pot 2
# 			Hertha Berlin: 10.64% ± 0.21%
# 			Maccabi Tel-Aviv: 9.29% ± 0.16%
# 			BATE Borisov: 8.69% ± 0.16%
# 			Real Sociedad: 8.66% ± 0.17%
# 			Nice: 8.54% ± 0.16%
# 			Young Boys: 8.49% ± 0.20%
# 			FCSB: 8.46% ± 0.16%
# 			Ludogorets Razgrad: 8.32% ± 0.16%
# 			Lokomotiv Moscow: 7.83% ± 0.17%
# 			Marseille: 7.10% ± 0.16%
# 			Everton: 7.04% ± 0.16%
# 			Austria Wien: 6.95% ± 0.15%
# 		Rivals in pot 4
# 			Zlín: 8.80% ± 0.21%
# 			Östersund: 8.73% ± 0.18%
# 			Vardar: 8.71% ± 0.15%
# 			Skënderbeu: 8.64% ± 0.19%
# 			Vitesse: 8.63% ± 0.17%
# 			Apollon Limassol: 8.63% ± 0.17%
# 			AEK Athens: 8.62% ± 0.18%
# 			Konyaspor: 8.52% ± 0.19%
# 			İstanbul Başakşehir: 8.42% ± 0.18%
# 			Crvena Zvezda: 7.44% ± 0.15%
# 			Slavia Praha: 7.43% ± 0.17%
# 			Lugano: 7.42% ± 0.16%
# 	Vitória SC
# 		Rivals in pot 1
# 			Zenit: 10.03% ± 0.19%
# 			Lazio: 9.84% ± 0.17%
# 			AC Milan: 9.69% ± 0.17%
# 			Athletic Club: 9.37% ± 0.19%
# 			Villarreal: 9.25% ± 0.18%
# 			København: 8.72% ± 0.17%
# 			Dynamo Kyiv: 8.71% ± 0.17%
# 			Lyon: 8.67% ± 0.19%
# 			Arsenal: 8.67% ± 0.20%
# 			Salzburg: 8.53% ± 0.20%
# 			Viktoria Plzeň: 8.52% ± 0.19%
# 		Rivals in pot 2
# 			Lokomotiv Moscow: 10.66% ± 0.19%
# 			Marseille: 9.59% ± 0.18%
# 			Austria Wien: 9.52% ± 0.18%
# 			Everton: 9.49% ± 0.20%
# 			Hertha Berlin: 8.29% ± 0.18%
# 			Nice: 7.68% ± 0.16%
# 			FCSB: 7.58% ± 0.18%
# 			BATE Borisov: 7.56% ± 0.17%
# 			Ludogorets Razgrad: 7.52% ± 0.19%
# 			Young Boys: 7.51% ± 0.16%
# 			Real Sociedad: 7.34% ± 0.16%
# 			Maccabi Tel-Aviv: 7.24% ± 0.15%
# 		Rivals in pot 4
# 			Crvena Zvezda: 12.21% ± 0.20%
# 			Lugano: 10.55% ± 0.18%
# 			Slavia Praha: 9.66% ± 0.16%
# 			Konyaspor: 8.09% ± 0.17%
# 			İstanbul Başakşehir: 8.07% ± 0.16%
# 			Vardar: 7.40% ± 0.17%
# 			Apollon Limassol: 7.39% ± 0.17%
# 			Skënderbeu: 7.39% ± 0.17%
# 			Östersund: 7.38% ± 0.17%
# 			AEK Athens: 7.37% ± 0.17%
# 			Zlín: 7.27% ± 0.17%
# 			Vitesse: 7.21% ± 0.16%
# 	Partizan
# 		Rivals in pot 1
# 			Zenit: 9.07% ± 0.18%
# 			Dynamo Kyiv: 9.05% ± 0.20%
# 			Braga: 8.94% ± 0.18%
# 			AC Milan: 8.66% ± 0.17%
# 			Lazio: 8.60% ± 0.15%
# 			Lyon: 8.38% ± 0.17%
# 			Arsenal: 8.28% ± 0.17%
# 			Salzburg: 8.04% ± 0.17%
# 			København: 7.90% ± 0.16%
# 			Viktoria Plzeň: 7.83% ± 0.18%
# 			Villarreal: 7.71% ± 0.17%
# 			Athletic Club: 7.55% ± 0.16%
# 		Rivals in pot 2
# 			Hertha Berlin: 10.51% ± 0.17%
# 			Maccabi Tel-Aviv: 9.45% ± 0.20%
# 			Nice: 8.59% ± 0.19%
# 			Real Sociedad: 8.58% ± 0.19%
# 			Ludogorets Razgrad: 8.57% ± 0.20%
# 			BATE Borisov: 8.50% ± 0.16%
# 			Young Boys: 8.50% ± 0.17%
# 			FCSB: 8.47% ± 0.16%
# 			Lokomotiv Moscow: 7.85% ± 0.18%
# 			Austria Wien: 7.02% ± 0.17%
# 			Marseille: 7.02% ± 0.17%
# 			Everton: 6.94% ± 0.15%
# 		Rivals in pot 4
# 			Apollon Limassol: 9.86% ± 0.22%
# 			Zlín: 9.84% ± 0.18%
# 			Vitesse: 9.82% ± 0.17%
# 			Vardar: 9.80% ± 0.20%
# 			AEK Athens: 9.73% ± 0.20%
# 			Östersund: 9.69% ± 0.19%
# 			Skënderbeu: 9.57% ± 0.20%
# 			Konyaspor: 8.47% ± 0.15%
# 			İstanbul Başakşehir: 8.45% ± 0.20%
# 			Slavia Praha: 7.45% ± 0.16%
# 			Lugano: 7.31% ± 0.16%
# 	Zorya Luhansk
# 		Rivals in pot 1
# 			Lazio: 10.51% ± 0.18%
# 			AC Milan: 10.30% ± 0.20%
# 			Arsenal: 10.05% ± 0.21%
# 			Salzburg: 9.98% ± 0.18%
# 			Lyon: 9.97% ± 0.16%
# 			Viktoria Plzeň: 9.94% ± 0.20%
# 			Braga: 9.88% ± 0.16%
# 			København: 9.86% ± 0.19%
# 			Athletic Club: 9.78% ± 0.20%
# 			Villarreal: 9.73% ± 0.17%
# 		Rivals in pot 2
# 			Everton: 10.64% ± 0.19%
# 			Austria Wien: 10.58% ± 0.18%
# 			Marseille: 10.40% ± 0.19%
# 			Hertha Berlin: 9.19% ± 0.17%
# 			FCSB: 8.64% ± 0.19%
# 			Ludogorets Razgrad: 8.59% ± 0.19%
# 			Maccabi Tel-Aviv: 8.54% ± 0.17%
# 			BATE Borisov: 8.46% ± 0.17%
# 			Nice: 8.45% ± 0.19%
# 			Young Boys: 8.39% ± 0.17%
# 			Real Sociedad: 8.12% ± 0.16%
# 		Rivals in pot 4
# 			Crvena Zvezda: 11.43% ± 0.22%
# 			Lugano: 10.02% ± 0.17%
# 			Slavia Praha: 9.29% ± 0.17%
# 			Konyaspor: 8.31% ± 0.14%
# 			İstanbul Başakşehir: 8.20% ± 0.17%
# 			Vardar: 7.66% ± 0.19%
# 			Apollon Limassol: 7.61% ± 0.16%
# 			AEK Athens: 7.61% ± 0.16%
# 			Vitesse: 7.55% ± 0.17%
# 			Östersund: 7.48% ± 0.15%
# 			Zlín: 7.44% ± 0.16%
# 			Skënderbeu: 7.40% ± 0.17%
# Clubs in pot 4
# 	Skënderbeu
# 		Rivals in pot 1
# 			Viktoria Plzeň: 10.68% ± 0.22%
# 			Salzburg: 8.43% ± 0.16%
# 			Arsenal: 8.41% ± 0.18%
# 			Braga: 8.36% ± 0.16%
# 			Dynamo Kyiv: 8.35% ± 0.16%
# 			Lyon: 8.32% ± 0.18%
# 			Zenit: 8.31% ± 0.17%
# 			København: 8.12% ± 0.14%
# 			Athletic Club: 7.93% ± 0.16%
# 			Villarreal: 7.91% ± 0.16%
# 			Lazio: 7.63% ± 0.17%
# 			AC Milan: 7.55% ± 0.19%
# 		Rivals in pot 2
# 			Young Boys: 9.77% ± 0.18%
# 			Maccabi Tel-Aviv: 8.82% ± 0.18%
# 			BATE Borisov: 8.77% ± 0.19%
# 			Nice: 8.72% ± 0.15%
# 			Ludogorets Razgrad: 8.67% ± 0.18%
# 			Real Sociedad: 8.66% ± 0.19%
# 			Hertha Berlin: 8.61% ± 0.18%
# 			FCSB: 8.55% ± 0.17%
# 			Marseille: 7.39% ± 0.15%
# 			Lokomotiv Moscow: 7.35% ± 0.17%
# 			Everton: 7.35% ± 0.18%
# 			Austria Wien: 7.35% ± 0.17%
# 		Rivals in pot 3
# 			Partizan: 9.57% ± 0.20%
# 			Köln: 8.85% ± 0.18%
# 			Rijeka: 8.76% ± 0.19%
# 			Astana: 8.75% ± 0.18%
# 			Atalanta: 8.74% ± 0.18%
# 			Sheriff Tiraspol: 8.72% ± 0.17%
# 			Rosenborg: 8.64% ± 0.19%
# 			Zulte Waregem: 8.60% ± 0.16%
# 			Zorya Luhansk: 7.40% ± 0.17%
# 			Vitória SC: 7.39% ± 0.17%
# 			Hapoel Beer-Sheva: 7.32% ± 0.15%
# 			Hoffenheim: 7.25% ± 0.18%
# 	Apollon Limassol
# 		Rivals in pot 1
# 			Viktoria Plzeň: 10.59% ± 0.19%
# 			Lyon: 8.44% ± 0.18%
# 			Arsenal: 8.43% ± 0.17%
# 			Zenit: 8.39% ± 0.18%
# 			Salzburg: 8.33% ± 0.19%
# 			Dynamo Kyiv: 8.30% ± 0.17%
# 			København: 8.21% ± 0.18%
# 			Braga: 8.17% ± 0.15%
# 			AC Milan: 7.86% ± 0.16%
# 			Lazio: 7.80% ± 0.17%
# 			Villarreal: 7.78% ± 0.16%
# 			Athletic Club: 7.71% ± 0.18%
# 		Rivals in pot 2
# 			Young Boys: 9.74% ± 0.17%
# 			Hertha Berlin: 9.06% ± 0.20%
# 			Maccabi Tel-Aviv: 8.88% ± 0.19%
# 			Ludogorets Razgrad: 8.66% ± 0.20%
# 			FCSB: 8.65% ± 0.19%
# 			Real Sociedad: 8.65% ± 0.18%
# 			BATE Borisov: 8.62% ± 0.17%
# 			Nice: 8.56% ± 0.18%
# 			Lokomotiv Moscow: 7.37% ± 0.17%
# 			Everton: 7.35% ± 0.16%
# 			Marseille: 7.29% ± 0.16%
# 			Austria Wien: 7.18% ± 0.16%
# 		Rivals in pot 3
# 			Partizan: 9.86% ± 0.22%
# 			Sheriff Tiraspol: 8.72% ± 0.17%
# 			Köln: 8.72% ± 0.17%
# 			Atalanta: 8.69% ± 0.14%
# 			Zulte Waregem: 8.67% ± 0.16%
# 			Astana: 8.66% ± 0.18%
# 			Rosenborg: 8.63% ± 0.17%
# 			Rijeka: 8.56% ± 0.16%
# 			Zorya Luhansk: 7.61% ± 0.16%
# 			Vitória SC: 7.39% ± 0.17%
# 			Hapoel Beer-Sheva: 7.29% ± 0.19%
# 			Hoffenheim: 7.20% ± 0.14%
# 	Slavia Praha
# 		Rivals in pot 1
# 			AC Milan: 9.52% ± 0.19%
# 			Villarreal: 9.45% ± 0.20%
# 			Lazio: 9.44% ± 0.22%
# 			Athletic Club: 9.44% ± 0.20%
# 			Zenit: 9.01% ± 0.19%
# 			Salzburg: 8.91% ± 0.20%
# 			København: 8.89% ± 0.19%
# 			Arsenal: 8.86% ± 0.18%
# 			Lyon: 8.86% ± 0.17%
# 			Braga: 8.81% ± 0.19%
# 			Dynamo Kyiv: 8.81% ± 0.16%
# 		Rivals in pot 2
# 			Marseille: 9.82% ± 0.20%
# 			Austria Wien: 9.80% ± 0.21%
# 			Everton: 9.79% ± 0.20%
# 			Lokomotiv Moscow: 9.65% ± 0.19%
# 			Nice: 7.76% ± 0.17%
# 			FCSB: 7.75% ± 0.18%
# 			Maccabi Tel-Aviv: 7.69% ± 0.16%
# 			BATE Borisov: 7.61% ± 0.17%
# 			Hertha Berlin: 7.59% ± 0.16%
# 			Ludogorets Razgrad: 7.56% ± 0.15%
# 			Young Boys: 7.51% ± 0.16%
# 			Real Sociedad: 7.48% ± 0.16%
# 		Rivals in pot 3
# 			Hoffenheim: 10.61% ± 0.19%
# 			Hapoel Beer-Sheva: 10.53% ± 0.20%
# 			Vitória SC: 9.66% ± 0.16%
# 			Zorya Luhansk: 9.29% ± 0.17%
# 			Rijeka: 7.65% ± 0.16%
# 			Astana: 7.63% ± 0.16%
# 			Zulte Waregem: 7.62% ± 0.17%
# 			Köln: 7.49% ± 0.15%
# 			Partizan: 7.45% ± 0.16%
# 			Rosenborg: 7.43% ± 0.17%
# 			Sheriff Tiraspol: 7.40% ± 0.18%
# 			Atalanta: 7.24% ± 0.16%
# 	Zlín
# 		Rivals in pot 1
# 			Arsenal: 9.47% ± 0.18%
# 			Lyon: 9.41% ± 0.18%
# 			Braga: 9.40% ± 0.19%
# 			Zenit: 9.31% ± 0.17%
# 			Dynamo Kyiv: 9.30% ± 0.17%
# 			Salzburg: 9.27% ± 0.18%
# 			København: 9.17% ± 0.18%
# 			AC Milan: 8.76% ± 0.19%
# 			Villarreal: 8.71% ± 0.18%
# 			Athletic Club: 8.64% ± 0.18%
# 			Lazio: 8.58% ± 0.19%
# 		Rivals in pot 2
# 			Young Boys: 9.80% ± 0.20%
# 			Maccabi Tel-Aviv: 8.94% ± 0.19%
# 			Hertha Berlin: 8.87% ± 0.17%
# 			Ludogorets Razgrad: 8.84% ± 0.17%
# 			FCSB: 8.78% ± 0.20%
# 			Nice: 8.67% ± 0.18%
# 			BATE Borisov: 8.62% ± 0.16%
# 			Real Sociedad: 8.54% ± 0.18%
# 			Marseille: 7.34% ± 0.17%
# 			Austria Wien: 7.32% ± 0.15%
# 			Everton: 7.21% ± 0.16%
# 			Lokomotiv Moscow: 7.08% ± 0.15%
# 		Rivals in pot 3
# 			Partizan: 9.84% ± 0.18%
# 			Rosenborg: 8.80% ± 0.21%
# 			Sheriff Tiraspol: 8.75% ± 0.17%
# 			Zulte Waregem: 8.69% ± 0.17%
# 			Köln: 8.68% ± 0.20%
# 			Rijeka: 8.63% ± 0.19%
# 			Astana: 8.62% ± 0.19%
# 			Atalanta: 8.59% ± 0.17%
# 			Zorya Luhansk: 7.44% ± 0.16%
# 			Hoffenheim: 7.37% ± 0.17%
# 			Hapoel Beer-Sheva: 7.30% ± 0.16%
# 			Vitória SC: 7.27% ± 0.17%
# 	AEK Athens
# 		Rivals in pot 1
# 			Viktoria Plzeň: 10.70% ± 0.21%
# 			Dynamo Kyiv: 8.39% ± 0.15%
# 			Lyon: 8.35% ± 0.15%
# 			Braga: 8.35% ± 0.15%
# 			Salzburg: 8.28% ± 0.19%
# 			København: 8.28% ± 0.17%
# 			Arsenal: 8.22% ± 0.18%
# 			Zenit: 8.10% ± 0.16%
# 			Lazio: 7.92% ± 0.17%
# 			Athletic Club: 7.90% ± 0.18%
# 			AC Milan: 7.79% ± 0.16%
# 			Villarreal: 7.73% ± 0.20%
# 		Rivals in pot 2
# 			Young Boys: 9.73% ± 0.20%
# 			Maccabi Tel-Aviv: 8.79% ± 0.19%
# 			Real Sociedad: 8.76% ± 0.19%
# 			Nice: 8.75% ± 0.18%
# 			Hertha Berlin: 8.71% ± 0.16%
# 			BATE Borisov: 8.64% ± 0.17%
# 			Ludogorets Razgrad: 8.61% ± 0.17%
# 			FCSB: 8.55% ± 0.19%
# 			Lokomotiv Moscow: 7.44% ± 0.17%
# 			Everton: 7.42% ± 0.14%
# 			Austria Wien: 7.30% ± 0.16%
# 			Marseille: 7.28% ± 0.17%
# 		Rivals in pot 3
# 			Partizan: 9.73% ± 0.20%
# 			Atalanta: 8.79% ± 0.17%
# 			Astana: 8.73% ± 0.19%
# 			Sheriff Tiraspol: 8.69% ± 0.19%
# 			Köln: 8.66% ± 0.18%
# 			Rijeka: 8.62% ± 0.17%
# 			Rosenborg: 8.62% ± 0.18%
# 			Zulte Waregem: 8.60% ± 0.16%
# 			Zorya Luhansk: 7.61% ± 0.16%
# 			Hoffenheim: 7.42% ± 0.17%
# 			Vitória SC: 7.37% ± 0.17%
# 			Hapoel Beer-Sheva: 7.15% ± 0.16%
# 	Vardar
# 		Rivals in pot 1
# 			Viktoria Plzeň: 10.68% ± 0.18%
# 			Zenit: 8.47% ± 0.16%
# 			Arsenal: 8.38% ± 0.19%
# 			Salzburg: 8.35% ± 0.16%
# 			Lyon: 8.29% ± 0.15%
# 			Braga: 8.29% ± 0.17%
# 			Dynamo Kyiv: 8.23% ± 0.17%
# 			København: 8.22% ± 0.17%
# 			Villarreal: 7.84% ± 0.17%
# 			Lazio: 7.84% ± 0.16%
# 			Athletic Club: 7.71% ± 0.20%
# 			AC Milan: 7.70% ± 0.18%
# 		Rivals in pot 2
# 			Young Boys: 9.77% ± 0.18%
# 			Maccabi Tel-Aviv: 8.89% ± 0.17%
# 			Real Sociedad: 8.87% ± 0.18%
# 			FCSB: 8.70% ± 0.18%
# 			BATE Borisov: 8.69% ± 0.17%
# 			Hertha Berlin: 8.67% ± 0.18%
# 			Nice: 8.63% ± 0.16%
# 			Ludogorets Razgrad: 8.59% ± 0.17%
# 			Lokomotiv Moscow: 7.35% ± 0.18%
# 			Marseille: 7.33% ± 0.19%
# 			Austria Wien: 7.29% ± 0.16%
# 			Everton: 7.23% ± 0.19%
# 		Rivals in pot 3
# 			Partizan: 9.80% ± 0.20%
# 			Köln: 8.76% ± 0.19%
# 			Sheriff Tiraspol: 8.72% ± 0.19%
# 			Rosenborg: 8.71% ± 0.15%
# 			Rijeka: 8.69% ± 0.16%
# 			Atalanta: 8.68% ± 0.16%
# 			Astana: 8.57% ± 0.18%
# 			Zulte Waregem: 8.51% ± 0.19%
# 			Zorya Luhansk: 7.66% ± 0.19%
# 			Vitória SC: 7.40% ± 0.17%
# 			Hapoel Beer-Sheva: 7.25% ± 0.15%
# 			Hoffenheim: 7.24% ± 0.17%
# 	Vitesse
# 		Rivals in pot 1
# 			Viktoria Plzeň: 10.63% ± 0.21%
# 			Zenit: 8.48% ± 0.17%
# 			Arsenal: 8.42% ± 0.18%
# 			Dynamo Kyiv: 8.37% ± 0.18%
# 			Braga: 8.34% ± 0.17%
# 			Lyon: 8.31% ± 0.17%
# 			Salzburg: 8.28% ± 0.17%
# 			København: 8.10% ± 0.17%
# 			AC Milan: 7.83% ± 0.19%
# 			Athletic Club: 7.78% ± 0.17%
# 			Villarreal: 7.78% ± 0.19%
# 			Lazio: 7.67% ± 0.17%
# 		Rivals in pot 2
# 			Young Boys: 9.79% ± 0.17%
# 			Real Sociedad: 8.87% ± 0.17%
# 			Hertha Berlin: 8.85% ± 0.19%
# 			BATE Borisov: 8.83% ± 0.17%
# 			FCSB: 8.73% ± 0.17%
# 			Maccabi Tel-Aviv: 8.68% ± 0.16%
# 			Nice: 8.68% ± 0.15%
# 			Ludogorets Razgrad: 8.60% ± 0.19%
# 			Lokomotiv Moscow: 7.37% ± 0.16%
# 			Austria Wien: 7.24% ± 0.16%
# 			Marseille: 7.20% ± 0.16%
# 			Everton: 7.18% ± 0.17%
# 		Rivals in pot 3
# 			Partizan: 9.82% ± 0.17%
# 			Atalanta: 8.81% ± 0.19%
# 			Köln: 8.73% ± 0.18%
# 			Zulte Waregem: 8.70% ± 0.17%
# 			Sheriff Tiraspol: 8.70% ± 0.18%
# 			Astana: 8.65% ± 0.18%
# 			Rijeka: 8.64% ± 0.16%
# 			Rosenborg: 8.63% ± 0.17%
# 			Zorya Luhansk: 7.55% ± 0.17%
# 			Hoffenheim: 7.30% ± 0.18%
# 			Hapoel Beer-Sheva: 7.25% ± 0.16%
# 			Vitória SC: 7.21% ± 0.16%
# 	Crvena Zvezda
# 		Rivals in pot 1
# 			Athletic Club: 9.53% ± 0.17%
# 			AC Milan: 9.50% ± 0.17%
# 			Villarreal: 9.36% ± 0.19%
# 			Lazio: 9.35% ± 0.19%
# 			Viktoria Plzeň: 8.69% ± 0.18%
# 			København: 8.12% ± 0.17%
# 			Arsenal: 7.86% ± 0.17%
# 			Zenit: 7.83% ± 0.16%
# 			Salzburg: 7.82% ± 0.15%
# 			Lyon: 7.79% ± 0.15%
# 			Dynamo Kyiv: 7.12% ± 0.17%
# 			Braga: 7.02% ± 0.17%
# 		Rivals in pot 2
# 			Austria Wien: 11.15% ± 0.20%
# 			Everton: 11.07% ± 0.17%
# 			Marseille: 11.05% ± 0.21%
# 			Lokomotiv Moscow: 10.93% ± 0.19%
# 			Nice: 7.34% ± 0.17%
# 			Real Sociedad: 7.32% ± 0.15%
# 			FCSB: 7.24% ± 0.19%
# 			Ludogorets Razgrad: 7.23% ± 0.18%
# 			BATE Borisov: 7.16% ± 0.17%
# 			Young Boys: 7.15% ± 0.18%
# 			Hertha Berlin: 6.22% ± 0.14%
# 			Maccabi Tel-Aviv: 6.14% ± 0.14%
# 		Rivals in pot 3
# 			Hapoel Beer-Sheva: 12.26% ± 0.20%
# 			Vitória SC: 12.21% ± 0.20%
# 			Hoffenheim: 12.21% ± 0.22%
# 			Zorya Luhansk: 11.43% ± 0.22%
# 			Köln: 7.49% ± 0.18%
# 			Zulte Waregem: 7.47% ± 0.17%
# 			Rosenborg: 7.44% ± 0.15%
# 			Rijeka: 7.40% ± 0.16%
# 			Atalanta: 7.39% ± 0.15%
# 			Astana: 7.38% ± 0.16%
# 			Sheriff Tiraspol: 7.31% ± 0.16%
# 	Lugano
# 		Rivals in pot 1
# 			Lazio: 9.41% ± 0.22%
# 			Villarreal: 9.40% ± 0.19%
# 			AC Milan: 9.39% ± 0.20%
# 			Athletic Club: 9.31% ± 0.18%
# 			Viktoria Plzeň: 8.86% ± 0.18%
# 			København: 8.39% ± 0.19%
# 			Braga: 8.36% ± 0.16%
# 			Dynamo Kyiv: 8.18% ± 0.19%
# 			Zenit: 7.26% ± 0.16%
# 			Salzburg: 7.22% ± 0.17%
# 			Arsenal: 7.14% ± 0.17%
# 			Lyon: 7.09% ± 0.16%
# 		Rivals in pot 2
# 			Everton: 12.07% ± 0.18%
# 			Austria Wien: 12.01% ± 0.22%
# 			Lokomotiv Moscow: 11.94% ± 0.20%
# 			Marseille: 11.78% ± 0.21%
# 			Ludogorets Razgrad: 7.51% ± 0.16%
# 			Hertha Berlin: 7.51% ± 0.17%
# 			Nice: 7.50% ± 0.15%
# 			Maccabi Tel-Aviv: 7.46% ± 0.17%
# 			Real Sociedad: 7.45% ± 0.15%
# 			FCSB: 7.42% ± 0.16%
# 			BATE Borisov: 7.36% ± 0.16%
# 		Rivals in pot 3
# 			Vitória SC: 10.55% ± 0.18%
# 			Hapoel Beer-Sheva: 10.15% ± 0.17%
# 			Hoffenheim: 10.06% ± 0.18%
# 			Zorya Luhansk: 10.02% ± 0.17%
# 			Sheriff Tiraspol: 7.52% ± 0.17%
# 			Astana: 7.47% ± 0.18%
# 			Zulte Waregem: 7.44% ± 0.15%
# 			Rosenborg: 7.42% ± 0.16%
# 			Rijeka: 7.40% ± 0.16%
# 			Atalanta: 7.37% ± 0.15%
# 			Partizan: 7.31% ± 0.16%
# 			Köln: 7.30% ± 0.16%
# 	Östersund
# 		Rivals in pot 1
# 			Viktoria Plzeň: 10.71% ± 0.20%
# 			Lyon: 8.41% ± 0.17%
# 			Dynamo Kyiv: 8.31% ± 0.18%
# 			Braga: 8.27% ± 0.16%
# 			Salzburg: 8.25% ± 0.17%
# 			Arsenal: 8.24% ± 0.17%
# 			Zenit: 8.21% ± 0.18%
# 			København: 8.18% ± 0.18%
# 			AC Milan: 7.91% ± 0.19%
# 			Lazio: 7.86% ± 0.16%
# 			Athletic Club: 7.83% ± 0.18%
# 			Villarreal: 7.82% ± 0.16%
# 		Rivals in pot 2
# 			Young Boys: 9.92% ± 0.18%
# 			Hertha Berlin: 8.85% ± 0.19%
# 			Maccabi Tel-Aviv: 8.75% ± 0.20%
# 			BATE Borisov: 8.73% ± 0.17%
# 			FCSB: 8.64% ± 0.16%
# 			Nice: 8.63% ± 0.18%
# 			Ludogorets Razgrad: 8.62% ± 0.20%
# 			Real Sociedad: 8.46% ± 0.18%
# 			Lokomotiv Moscow: 7.41% ± 0.15%
# 			Marseille: 7.36% ± 0.18%
# 			Austria Wien: 7.34% ± 0.17%
# 			Everton: 7.29% ± 0.16%
# 		Rivals in pot 3
# 			Partizan: 9.69% ± 0.19%
# 			Zulte Waregem: 8.79% ± 0.16%
# 			Atalanta: 8.75% ± 0.19%
# 			Rosenborg: 8.73% ± 0.18%
# 			Rijeka: 8.66% ± 0.18%
# 			Sheriff Tiraspol: 8.64% ± 0.18%
# 			Astana: 8.63% ± 0.17%
# 			Köln: 8.59% ± 0.16%
# 			Zorya Luhansk: 7.48% ± 0.15%
# 			Hapoel Beer-Sheva: 7.43% ± 0.17%
# 			Vitória SC: 7.38% ± 0.17%
# 			Hoffenheim: 7.22% ± 0.14%
# 	İstanbul Başakşehir
# 		Rivals in pot 1
# 			Viktoria Plzeň: 9.34% ± 0.18%
# 			Salzburg: 8.42% ± 0.18%
# 			Braga: 8.41% ± 0.19%
# 			Lyon: 8.39% ± 0.18%
# 			Lazio: 8.35% ± 0.19%
# 			Arsenal: 8.27% ± 0.17%
# 			Zenit: 8.23% ± 0.17%
# 			Dynamo Kyiv: 8.19% ± 0.18%
# 			København: 8.13% ± 0.17%
# 			Athletic Club: 8.12% ± 0.15%
# 			Villarreal: 8.10% ± 0.17%
# 			AC Milan: 8.04% ± 0.17%
# 		Rivals in pot 2
# 			Hertha Berlin: 8.62% ± 0.16%
# 			Ludogorets Razgrad: 8.50% ± 0.17%
# 			Real Sociedad: 8.50% ± 0.18%
# 			Maccabi Tel-Aviv: 8.48% ± 0.16%
# 			FCSB: 8.48% ± 0.17%
# 			BATE Borisov: 8.47% ± 0.16%
# 			Young Boys: 8.36% ± 0.17%
# 			Nice: 8.35% ± 0.17%
# 			Everton: 8.12% ± 0.17%
# 			Marseille: 8.10% ± 0.17%
# 			Lokomotiv Moscow: 8.09% ± 0.17%
# 			Austria Wien: 7.92% ± 0.16%
# 		Rivals in pot 3
# 			Atalanta: 8.61% ± 0.19%
# 			Zulte Waregem: 8.56% ± 0.17%
# 			Rijeka: 8.53% ± 0.17%
# 			Astana: 8.49% ± 0.19%
# 			Sheriff Tiraspol: 8.47% ± 0.17%
# 			Partizan: 8.45% ± 0.20%
# 			Rosenborg: 8.42% ± 0.18%
# 			Köln: 8.23% ± 0.17%
# 			Zorya Luhansk: 8.20% ± 0.17%
# 			Vitória SC: 8.07% ± 0.16%
# 			Hoffenheim: 8.00% ± 0.21%
# 			Hapoel Beer-Sheva: 7.97% ± 0.17%
# 	Konyaspor
# 		Rivals in pot 1
# 			Viktoria Plzeň: 9.13% ± 0.18%
# 			Dynamo Kyiv: 8.45% ± 0.18%
# 			Salzburg: 8.44% ± 0.19%
# 			Zenit: 8.40% ± 0.16%
# 			Lyon: 8.35% ± 0.19%
# 			Arsenal: 8.29% ± 0.15%
# 			Braga: 8.22% ± 0.18%
# 			København: 8.21% ± 0.19%
# 			Lazio: 8.15% ± 0.18%
# 			AC Milan: 8.15% ± 0.16%
# 			Villarreal: 8.11% ± 0.15%
# 			Athletic Club: 8.10% ± 0.18%
# 		Rivals in pot 2
# 			Ludogorets Razgrad: 8.62% ± 0.19%
# 			FCSB: 8.52% ± 0.19%
# 			BATE Borisov: 8.50% ± 0.16%
# 			Maccabi Tel-Aviv: 8.48% ± 0.19%
# 			Young Boys: 8.47% ± 0.17%
# 			Real Sociedad: 8.45% ± 0.19%
# 			Hertha Berlin: 8.42% ± 0.18%
# 			Nice: 8.41% ± 0.18%
# 			Austria Wien: 8.10% ± 0.19%
# 			Marseille: 8.07% ± 0.16%
# 			Lokomotiv Moscow: 8.03% ± 0.17%
# 			Everton: 7.92% ± 0.17%
# 		Rivals in pot 3
# 			Rosenborg: 8.52% ± 0.19%
# 			Köln: 8.50% ± 0.17%
# 			Partizan: 8.47% ± 0.15%
# 			Rijeka: 8.44% ± 0.17%
# 			Astana: 8.42% ± 0.15%
# 			Sheriff Tiraspol: 8.36% ± 0.17%
# 			Atalanta: 8.35% ± 0.17%
# 			Zulte Waregem: 8.34% ± 0.16%
# 			Zorya Luhansk: 8.31% ± 0.14%
# 			Hoffenheim: 8.13% ± 0.19%
# 			Hapoel Beer-Sheva: 8.09% ± 0.17%
# 			Vitória SC: 8.09% ± 0.17%
